# %%
# !apt-get update
# !apt install -y git
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1410 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [426 kB]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [395 kB]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2116 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [24.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2181 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2546 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [31.6 kB]
# Fetched 9382 kB in 1s (8234 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   git-man libasn1-8-heimdal libcurl3-gnutls liberror-perl libexpat1
#   libgdbm-compat4 libgdbm5 libgssapi3-heimdal libhcrypto4-heimdal
#   libheimbase1-heimdal libheimntlm0-heimdal libhx509-5-heimdal
#   libkrb5-26-heimdal libldap-2.4-2 libldap-common libnghttp2-14 libperl5.26
#   libpsl5 libroken18-heimdal librtmp1 libsasl2-2 libsasl2-modules
#   libsasl2-modules-db libsqlite3-0 libwind0-heimdal netbase patch perl
#   perl-modules-5.26 publicsuffix
# Suggested packages:
#   gettext-base git-daemon-run | git-daemon-sysvinit git-doc git-el git-email
#   git-gui gitk gitweb git-cvs git-mediawiki git-svn gdbm-l10n
#   libsasl2-modules-gssapi-mit | libsasl2-modules-gssapi-heimdal
#   libsasl2-modules-ldap libsasl2-modules-otp libsasl2-modules-sql ed
#   diffutils-doc perl-doc libterm-readline-gnu-perl
#   | libterm-readline-perl-perl make
# The following NEW packages will be installed:
#   git git-man libasn1-8-heimdal libcurl3-gnutls liberror-perl libexpat1
#   libgdbm-compat4 libgdbm5 libgssapi3-heimdal libhcrypto4-heimdal
#   libheimbase1-heimdal libheimntlm0-heimdal libhx509-5-heimdal
#   libkrb5-26-heimdal libldap-2.4-2 libldap-common libnghttp2-14 libperl5.26
#   libpsl5 libroken18-heimdal librtmp1 libsasl2-2 libsasl2-modules
#   libsasl2-modules-db libsqlite3-0 libwind0-heimdal netbase patch perl
#   perl-modules-5.26 publicsuffix
# 0 upgraded, 31 newly installed, 0 to remove and 10 not upgraded.
# Need to get 13.5 MB of archives.
# After this operation, 82.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 perl-modules-5.26 all 5.26.1-6ubuntu0.5 [2762 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdbm5 amd64 1.14.1-6 [26.0 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdbm-compat4 amd64 1.14.1-6 [6084 B]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libperl5.26 amd64 5.26.1-6ubuntu0.5 [3534 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 perl amd64 5.26.1-6ubuntu0.5 [201 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libexpat1 amd64 2.2.5-3ubuntu0.2 [80.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsqlite3-0 amd64 3.22.0-1ubuntu0.4 [499 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 netbase all 5.4 [12.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpsl5 amd64 0.19.1-5build1 [41.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 publicsuffix all 20180223.1310-1 [97.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libroken18-heimdal amd64 7.5.0+dfsg-1 [41.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libasn1-8-heimdal amd64 7.5.0+dfsg-1 [175 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libheimbase1-heimdal amd64 7.5.0+dfsg-1 [29.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhcrypto4-heimdal amd64 7.5.0+dfsg-1 [85.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwind0-heimdal amd64 7.5.0+dfsg-1 [47.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhx509-5-heimdal amd64 7.5.0+dfsg-1 [107 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libkrb5-26-heimdal amd64 7.5.0+dfsg-1 [206 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libheimntlm0-heimdal amd64 7.5.0+dfsg-1 [14.8 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgssapi3-heimdal amd64 7.5.0+dfsg-1 [96.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules-db amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [15.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-2 amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [49.2 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-common all 2.4.45+dfsg-1ubuntu1.10 [15.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-2.4-2 amd64 2.4.45+dfsg-1ubuntu1.10 [154 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnghttp2-14 amd64 1.30.0-1ubuntu1 [77.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 librtmp1 amd64 2.4+20151223.gitfa8646d.1-1 [54.2 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcurl3-gnutls amd64 7.58.0-2ubuntu3.13 [218 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 liberror-perl all 0.17025-1 [22.8 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 git-man all 1:2.17.1-1ubuntu0.8 [804 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 git amd64 1:2.17.1-1ubuntu0.8 [3916 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [48.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 patch amd64 2.7.6-2ubuntu1.1 [102 kB]
# Fetched 13.5 MB in 1s (23.8 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package perl-modules-5.26.
# (Reading database ... 6773 files and directories currently installed.)
# Preparing to unpack .../00-perl-modules-5.26_5.26.1-6ubuntu0.5_all.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking perl-modules-5.26 (5.26.1-6ubuntu0.5) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libgdbm5:amd64.
# Preparing to unpack .../01-libgdbm5_1.14.1-6_amd64.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking libgdbm5:amd64 (1.14.1-6) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libgdbm-compat4:amd64.
# Preparing to unpack .../02-libgdbm-compat4_1.14.1-6_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libgdbm-compat4:amd64 (1.14.1-6) ...
# 7Progress: [  5%] [##........................................................] 8Selecting previously unselected package libperl5.26:amd64.
# Preparing to unpack .../03-libperl5.26_5.26.1-6ubuntu0.5_amd64.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking libperl5.26:amd64 (5.26.1-6ubuntu0.5) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package perl.
# Preparing to unpack .../04-perl_5.26.1-6ubuntu0.5_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking perl (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package libexpat1:amd64.
# Preparing to unpack .../05-libexpat1_2.2.5-3ubuntu0.2_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libexpat1:amd64 (2.2.5-3ubuntu0.2) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libsqlite3-0:amd64.
# Preparing to unpack .../06-libsqlite3-0_3.22.0-1ubuntu0.4_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libsqlite3-0:amd64 (3.22.0-1ubuntu0.4) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package netbase.
# Preparing to unpack .../07-netbase_5.4_all.deb ...
# 7Progress: [ 14%] [########..................................................] 8Unpacking netbase (5.4) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libpsl5:amd64.
# Preparing to unpack .../08-libpsl5_0.19.1-5build1_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking libpsl5:amd64 (0.19.1-5build1) ...
# 7Progress: [ 17%] [##########................................................] 8Selecting previously unselected package publicsuffix.
# Preparing to unpack .../09-publicsuffix_20180223.1310-1_all.deb ...
# Unpacking publicsuffix (20180223.1310-1) ...
# 7Progress: [ 19%] [##########................................................] 87Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libroken18-heimdal:amd64.
# Preparing to unpack .../10-libroken18-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libroken18-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 21%] [###########...............................................] 87Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libasn1-8-heimdal:amd64.
# Preparing to unpack .../11-libasn1-8-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libasn1-8-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 22%] [#############.............................................] 87Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libheimbase1-heimdal:amd64.
# Preparing to unpack .../12-libheimbase1-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libheimbase1-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 24%] [##############............................................] 87Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libhcrypto4-heimdal:amd64.
# Preparing to unpack .../13-libhcrypto4-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libhcrypto4-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libwind0-heimdal:amd64.
# Preparing to unpack .../14-libwind0-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 28%] [###############...........................................] 8Unpacking libwind0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libhx509-5-heimdal:amd64.
# Preparing to unpack .../15-libhx509-5-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libhx509-5-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libkrb5-26-heimdal:amd64.
# Preparing to unpack .../16-libkrb5-26-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 31%] [##################........................................] 8Unpacking libkrb5-26-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libheimntlm0-heimdal:amd64.
# Preparing to unpack .../17-libheimntlm0-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking libheimntlm0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libgssapi3-heimdal:amd64.
# Preparing to unpack .../18-libgssapi3-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libgssapi3-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libsasl2-modules-db:amd64.
# Preparing to unpack .../19-libsasl2-modules-db_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package libsasl2-2:amd64.
# Preparing to unpack .../20-libsasl2-2_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package libldap-common.
# Preparing to unpack .../21-libldap-common_2.4.45+dfsg-1ubuntu1.10_all.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package libldap-2.4-2:amd64.
# Preparing to unpack .../22-libldap-2.4-2_2.4.45+dfsg-1ubuntu1.10_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 44%] [#########################.................................] 87Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libnghttp2-14:amd64.
# Preparing to unpack .../23-libnghttp2-14_1.30.0-1ubuntu1_amd64.deb ...
# Unpacking libnghttp2-14:amd64 (1.30.0-1ubuntu1) ...
# 7Progress: [ 46%] [##########################................................] 87Progress: [ 46%] [##########################................................] 8Selecting previously unselected package librtmp1:amd64.
# Preparing to unpack .../24-librtmp1_2.4+20151223.gitfa8646d.1-1_amd64.deb ...
# Unpacking librtmp1:amd64 (2.4+20151223.gitfa8646d.1-1) ...
# 7Progress: [ 47%] [###########################...............................] 87Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package libcurl3-gnutls:amd64.
# Preparing to unpack .../25-libcurl3-gnutls_7.58.0-2ubuntu3.13_amd64.deb ...
# Unpacking libcurl3-gnutls:amd64 (7.58.0-2ubuntu3.13) ...
# 7Progress: [ 49%] [############################..............................] 87Progress: [ 50%] [#############################.............................] 8Selecting previously unselected package liberror-perl.
# Preparing to unpack .../26-liberror-perl_0.17025-1_all.deb ...
# Unpacking liberror-perl (0.17025-1) ...
# 7Progress: [ 51%] [#############################.............................] 8Selecting previously unselected package git-man.
# Preparing to unpack .../27-git-man_1%3a2.17.1-1ubuntu0.8_all.deb ...
# 7Progress: [ 53%] [##############################............................] 8Unpacking git-man (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 53%] [##############################............................] 8Selecting previously unselected package git.
# Preparing to unpack .../28-git_1%3a2.17.1-1ubuntu0.8_amd64.deb ...
# 7Progress: [ 54%] [###############################...........................] 8Unpacking git (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 55%] [###############################...........................] 8Selecting previously unselected package libsasl2-modules:amd64.
# Preparing to unpack .../29-libsasl2-modules_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 56%] [################################..........................] 8Unpacking libsasl2-modules:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 57%] [#################################.........................] 8Selecting previously unselected package patch.
# Preparing to unpack .../30-patch_2.7.6-2ubuntu1.1_amd64.deb ...
# 7Progress: [ 58%] [#################################.........................] 8Unpacking patch (2.7.6-2ubuntu1.1) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up git-man (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libexpat1:amd64 (2.2.5-3ubuntu0.2) ...
# 7Progress: [ 62%] [###################################.......................] 87Progress: [ 62%] [####################################......................] 8Setting up libnghttp2-14:amd64 (1.30.0-1ubuntu1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libpsl5:amd64 (0.19.1-5build1) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 66%] [######################################....................] 8Setting up libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 67%] [#######################################...................] 8Setting up libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 69%] [#######################################...................] 8Setting up libroken18-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up librtmp1:amd64 (2.4+20151223.gitfa8646d.1-1) ...
# 7Progress: [ 71%] [########################################..................] 87Progress: [ 71%] [#########################################.................] 8Setting up perl-modules-5.26 (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 72%] [##########################################................] 8Setting up libgdbm5:amd64 (1.14.1-6) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up patch (2.7.6-2ubuntu1.1) ...
# 7Progress: [ 74%] [###########################################...............] 87Progress: [ 75%] [###########################################...............] 8Setting up publicsuffix (20180223.1310-1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libheimbase1-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 78%] [############################################..............] 8Setting up libsqlite3-0:amd64 (3.22.0-1ubuntu0.4) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libgdbm-compat4:amd64 (1.14.1-6) ...
# 7Progress: [ 79%] [##############################################............] 87Progress: [ 80%] [##############################################............] 8Setting up libsasl2-modules:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up netbase (5.4) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libwind0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libasn1-8-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 85%] [#################################################.........] 87Progress: [ 85%] [#################################################.........] 8Setting up libhcrypto4-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libhx509-5-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libperl5.26:amd64 (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 89%] [###################################################.......] 8Setting up libkrb5-26-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libheimntlm0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up perl (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libgssapi3-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 94%] [######################################################....] 87Progress: [ 94%] [######################################################....] 8Setting up liberror-perl (0.17025-1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libcurl3-gnutls:amd64 (7.58.0-2ubuntu3.13) ...
# 7Progress: [ 97%] [########################################################..] 87Progress: [ 98%] [########################################################..] 8Setting up git (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for libc-bin (2.27-3ubuntu1.4) ...
#
# 78

# %%
# !git clone https://gitlab.com/AdaptText/AdaptTextLib.git
# Out:
# Cloning into 'AdaptTextLib'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 780 (delta 85), reused 140 (delta 77), pack-reused 632
# Receiving objects: 100% (780/780), 1.43 MiB | 16.31 MiB/s, done.
# Resolving deltas: 100% (519/519), done.

# %%
# !cd AdaptTextLib && bash setup.sh
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 10 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Collecting wikiextractor==0.01
#   Downloading wikiextractor-0.1.tar.gz (36 kB)
# Collecting sentencepiece==0.1.95
#   Downloading sentencepiece-0.1.95-cp38-cp38-manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 11.8 MB/s eta 0:00:01
# Collecting ninja==1.10.0
#   Downloading ninja-1.10.0-py3-none-manylinux1_x86_64.whl (102 kB)
#      |████████████████████████████████| 102 kB 51.7 MB/s eta 0:00:01
# Collecting emoji==1.2.0
#   Downloading emoji-1.2.0-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 41.1 MB/s eta 0:00:01
# Collecting flask==1.1.2
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 5.5 MB/s  eta 0:00:01
# Collecting gunicorn==20.0.4
#   Downloading gunicorn-20.0.4-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 10.2 MB/s eta 0:00:01
# Requirement already satisfied: torch in /opt/conda/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (1.8.1)
# Collecting python-dotenv==0.15.0
#   Downloading python_dotenv-0.15.0-py2.py3-none-any.whl (18 kB)
# Collecting dropbox==11.2.0
#   Downloading dropbox-11.2.0-py3-none-any.whl (555 kB)
#      |████████████████████████████████| 555 kB 40.7 MB/s eta 0:00:01
# Collecting dataclasses==0.6
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting spacy==2.3.5
#   Downloading spacy-2.3.5-cp38-cp38-manylinux2014_x86_64.whl (10.5 MB)
#      |████████████████████████████████| 10.5 MB 35.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (1.19.2)
# Collecting matplotlib
#   Downloading matplotlib-3.4.1-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 28.6 MB/s eta 0:00:01    |██████████████████████████████▎ | 9.8 MB 28.6 MB/s eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.1-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      |████████████████████████████████| 24.9 MB 29.2 MB/s eta 0:00:01
# Collecting fastprogress
#   Downloading fastprogress-1.0.0-py3-none-any.whl (12 kB)
# Collecting scipy==1.6.1
#   Downloading scipy-1.6.1-cp38-cp38-manylinux1_x86_64.whl (27.3 MB)
#      |████████████████████████████████| 27.3 MB 94.3 MB/s eta 0:00:01
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting pandas
#   Downloading pandas-1.2.4-cp38-cp38-manylinux1_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 57.2 MB/s eta 0:00:01
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/conda/lib/python3.8/site-packages (from flask==1.1.2->-r requirements.txt (line 5)) (2.11.3)
# Collecting Werkzeug>=0.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 54.6 MB/s eta 0:00:01
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 2.5 MB/s  eta 0:00:01
# Requirement already satisfied: setuptools>=3.0 in /opt/conda/lib/python3.8/site-packages (from gunicorn==20.0.4->-r requirements.txt (line 6)) (50.3.1.post20201107)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.8/site-packages (from torch->-r requirements.txt (line 8)) (3.7.4.3)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.8/site-packages (from dropbox==11.2.0->-r requirements.txt (line 10)) (1.15.0)
# Requirement already satisfied: requests>=2.16.2 in /opt/conda/lib/python3.8/site-packages (from dropbox==11.2.0->-r requirements.txt (line 10)) (2.24.0)
# Collecting stone>=2.*
#   Downloading stone-3.2.1-py3-none-any.whl (160 kB)
#      |████████████████████████████████| 160 kB 101.8 MB/s eta 0:00:01
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp38-cp38-manylinux2014_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 44.4 MB/s eta 0:00:01
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp38-cp38-manylinux2014_x86_64.whl (35 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp38-cp38-manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 24.1 MB/s eta 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp38-cp38-manylinux2014_x86_64.whl (20 kB)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.5-cp38-cp38-manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 132.6 MB/s eta 0:00:01
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.8/site-packages (from spacy==2.3.5->-r requirements.txt (line 12)) (4.51.0)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.5-cp38-cp38-manylinux2014_x86_64.whl (186 kB)
#      |████████████████████████████████| 186 kB 132.9 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (8.1.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp38-cp38-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 37.7 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (2.4.7)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 40.3 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 20)) (2021.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from Jinja2>=2.10.1->flask==1.1.2->-r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (2020.12.5)
# Collecting ply>=3.4
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 10.5 MB/s eta 0:00:01
# Building wheels for collected packages: wikiextractor, sklearn
#   Building wheel for wikiextractor (setup.py) ... done
#   Created wheel for wikiextractor: filename=wikiextractor-0.1-py3-none-any.whl size=38819 sha256=8ddba4ed0d3ab53671dd33a847b273552b2582e8c343f6bc90f6bfec1caf5304
#   Stored in directory: /root/.cache/pip/wheels/98/50/4b/5a06f4f998b52f6b828af95aa4e1b3efb784b3210c970bcaf3
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=5ef7ea575a195fb7c9c929b7089e8756c286fb70ab636a11b173cc74fc828d76
#   Stored in directory: /root/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built wikiextractor sklearn
# Installing collected packages: wikiextractor, sentencepiece, ninja, emoji, Werkzeug, itsdangerous, click, flask, gunicorn, python-dotenv, ply, stone, dropbox, dataclasses, wasabi, catalogue, plac, cymem, murmurhash, preshed, blis, srsly, thinc, spacy, cycler, kiwisolver, matplotlib, threadpoolctl, joblib, scipy, scikit-learn, fastprogress, sklearn, pandas
# Successfully installed Werkzeug-1.0.1 blis-0.7.4 catalogue-1.0.0 click-7.1.2 cycler-0.10.0 cymem-2.0.5 dataclasses-0.6 dropbox-11.2.0 emoji-1.2.0 fastprogress-1.0.0 flask-1.1.2 gunicorn-20.0.4 itsdangerous-1.1.0 joblib-1.0.1 kiwisolver-1.3.1 matplotlib-3.4.1 murmurhash-1.0.5 ninja-1.10.0 pandas-1.2.4 plac-1.1.3 ply-3.11 preshed-3.0.5 python-dotenv-0.15.0 scikit-learn-0.24.1 scipy-1.6.1 sentencepiece-0.1.95 sklearn-0.0 spacy-2.3.5 srsly-1.0.5 stone-3.2.1 thinc-7.4.5 threadpoolctl-2.1.0 wasabi-0.8.2 wikiextractor-0.1
# Cloning into 'fastai1'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 155 (delta 29), reused 131 (delta 18), pack-reused 0
# Receiving objects: 100% (155/155), 207.89 KiB | 794.00 KiB/s, done.
# Resolving deltas: 100% (29/29), done.
# Cloning into 'Best-Deep-Learning-Optimizers'...
# remote: Enumerating objects: 211, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 211 (delta 14), reused 3 (delta 1), pack-reused 178
# Receiving objects: 100% (211/211), 858.72 KiB | 7.81 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
from AdaptTextLib.adapttext.adapt_text import AdaptText

lang = 'si'
app_root = "/storage"
bs = 128
splitting_ratio = 0.1
adapttext = AdaptText(lang, app_root, bs, splitting_ratio)

# %%
adapttext.prepare_pretrained_lm("one-outta-three.zip")

# %%
import pandas as pd

pd.set_option('display.max_colwidth', -1)
path_to_csv="sinhala-hate-speech-dataset.csv"
# path_to_csv="sentiment-news.csv"
# path_to_csv="hiru.csv"
df = pd.read_csv(path_to_csv)

text_name = "comment"
label_name = "label"

print(df.head())

classifierModelFWD, classifierModelBWD, ensembleModel, classes = adapttext.build_classifier(df, text_name, label_name, grad_unfreeze=True)
# Out:
#    id                                           comment  label
# 0  1   `හුදෙකලා´ එකේ `ද´ ඇහෙනවද කාටහරි                   0
# 1  2   18ක පෙනුමක් තියෙන්නේ                              0
# 2  3   2020 එනවා කිව්නාට මෙහෙම එයි කියලා හිතුවේ නෑ පට්ට  0
# 3  4   25 කැල්ල..හම්මෝ..                                 0
# 4  5   25 කෙල්ල අයියලගෙ කාලද කොහෙද ඉන්නෙ                 1
# 1    3455
# 0    2890
# Name: label, dtype: int64
# 1    3109
# 0    2601
# Name: label, dtype: int64
# 1    3109
# 0    2601
# Name: label, dtype: int64
# Training Forward model...
# [PosixPath('/storage/data/siwiki/models/si_wt'), PosixPath('/storage/data/siwiki/models/si_wt_vocab')]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       83.33% [5/6 00:04<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>10.072894</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>10.050014</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>9.995194</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>9.380790</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>8.583887</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='17' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       82.35% [14/17 00:00<00:00 12.5141]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 2.75E-02
# Min loss divided by 10: 6.31E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>7.907445</td>
#       <td>6.016751</td>
#       <td>0.790848</td>
#       <td>0.209152</td>
#       <td>410.243866</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.993586</td>
#       <td>5.807672</td>
#       <td>0.773884</td>
#       <td>0.226116</td>
#       <td>332.843231</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 6.016751289367676.
# Better model found at epoch 1 with valid_loss value: 5.807671546936035.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.116088</td>
#       <td>5.716653</td>
#       <td>0.773772</td>
#       <td>0.226228</td>
#       <td>303.886078</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.064321</td>
#       <td>5.554812</td>
#       <td>0.752344</td>
#       <td>0.247656</td>
#       <td>258.478485</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.901674</td>
#       <td>5.418356</td>
#       <td>0.746094</td>
#       <td>0.253906</td>
#       <td>225.508057</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.667867</td>
#       <td>5.346037</td>
#       <td>0.744754</td>
#       <td>0.255246</td>
#       <td>209.775299</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.396792</td>
#       <td>5.353328</td>
#       <td>0.748214</td>
#       <td>0.251786</td>
#       <td>211.310425</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.089195</td>
#       <td>5.457259</td>
#       <td>0.757143</td>
#       <td>0.242857</td>
#       <td>234.453827</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.748146</td>
#       <td>5.573068</td>
#       <td>0.763281</td>
#       <td>0.236719</td>
#       <td>263.240417</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.442347</td>
#       <td>5.615158</td>
#       <td>0.766071</td>
#       <td>0.233929</td>
#       <td>274.556915</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 5.716652870178223.
# Better model found at epoch 1 with valid_loss value: 5.554812431335449.
# Better model found at epoch 2 with valid_loss value: 5.418355941772461.
# Better model found at epoch 3 with valid_loss value: 5.346036911010742.
# Epoch 4: reducing lr to 0.012096801046885198
# Epoch 5: reducing lr to 0.006144321548587156
# Epoch 6: reducing lr to 0.0016614082101727287
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='94' class='' max='178' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.81% [94/178 00:02<00:01 1.0004]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 5.75E-04
# Min loss divided by 10: 3.02E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.512600</td>
#       <td>0.475820</td>
#       <td>0.771654</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.470870</td>
#       <td>0.433919</td>
#       <td>0.798425</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.446152</td>
#       <td>0.410080</td>
#       <td>0.815748</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.440843</td>
#       <td>0.442312</td>
#       <td>0.782677</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.406949</td>
#       <td>0.427897</td>
#       <td>0.792126</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.409873</td>
#       <td>0.420606</td>
#       <td>0.806299</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.382553</td>
#       <td>0.431328</td>
#       <td>0.798425</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.392714</td>
#       <td>0.427222</td>
#       <td>0.792126</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.384380</td>
#       <td>0.422882</td>
#       <td>0.803150</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.363500</td>
#       <td>0.421476</td>
#       <td>0.788976</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.348996</td>
#       <td>0.426724</td>
#       <td>0.790551</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.361635</td>
#       <td>0.422933</td>
#       <td>0.790551</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.4758204221725464.
# Better model found at epoch 1 with valid_loss value: 0.43391892313957214.
# Better model found at epoch 2 with valid_loss value: 0.4100800156593323.
# The accuracy is 0.8157480359077454 %.
# Gradual Unfreezing..
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.426163</td>
#       <td>0.418061</td>
#       <td>0.792126</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.434038</td>
#       <td>0.413960</td>
#       <td>0.800000</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.403693</td>
#       <td>0.398877</td>
#       <td>0.820472</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.367713</td>
#       <td>0.396678</td>
#       <td>0.804724</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.349444</td>
#       <td>0.410680</td>
#       <td>0.809449</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.321468</td>
#       <td>0.407529</td>
#       <td>0.806299</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.273466</td>
#       <td>0.401879</td>
#       <td>0.809449</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.272607</td>
#       <td>0.401020</td>
#       <td>0.811024</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.41806069016456604.
# Better model found at epoch 1 with valid_loss value: 0.41395989060401917.
# Better model found at epoch 2 with valid_loss value: 0.39887717366218567.
# Better model found at epoch 3 with valid_loss value: 0.3966781795024872.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.339836</td>
#       <td>0.394333</td>
#       <td>0.809449</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.314859</td>
#       <td>0.406106</td>
#       <td>0.793701</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.291209</td>
#       <td>0.406528</td>
#       <td>0.803150</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.217222</td>
#       <td>0.393753</td>
#       <td>0.833071</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.177698</td>
#       <td>0.392536</td>
#       <td>0.837795</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.153949</td>
#       <td>0.396849</td>
#       <td>0.837795</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.3943328857421875.
# Better model found at epoch 3 with valid_loss value: 0.39375296235084534.
# Better model found at epoch 4 with valid_loss value: 0.3925355076789856.
# Completely Unfreezing..
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='79' class='' max='178' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       44.38% [79/178 00:03<00:04 0.3724]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 7.59E-07
# Min loss divided by 10: 9.12E-06
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.164920</td>
#       <td>0.385722</td>
#       <td>0.829921</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.169146</td>
#       <td>0.393476</td>
#       <td>0.833071</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.168245</td>
#       <td>0.393123</td>
#       <td>0.831496</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.168282</td>
#       <td>0.393037</td>
#       <td>0.828346</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.160211</td>
#       <td>0.394389</td>
#       <td>0.831496</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.155363</td>
#       <td>0.391325</td>
#       <td>0.831496</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.38572198152542114.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.166851</td>
#       <td>0.394804</td>
#       <td>0.823622</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.171669</td>
#       <td>0.390975</td>
#       <td>0.829921</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.173891</td>
#       <td>0.396880</td>
#       <td>0.839370</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.174474</td>
#       <td>0.398357</td>
#       <td>0.834646</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.160409</td>
#       <td>0.391611</td>
#       <td>0.826772</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.170408</td>
#       <td>0.392945</td>
#       <td>0.828346</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.39480429887771606.
# Better model found at epoch 1 with valid_loss value: 0.3909745216369629.
# The accuracy is 0.8299212455749512 %.
# Training Backward model...
# [PosixPath('/storage/data/siwiki/models/si_wt_bwd'), PosixPath('/storage/data/siwiki/models/si_wt_vocab_bwd')]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       83.33% [5/6 00:04<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>9.845357</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>9.879254</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>9.850570</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>9.368717</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>8.613519</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='17' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       82.35% [14/17 00:00<00:00 13.5379]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 3.31E-02
# Min loss divided by 10: 7.59E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>7.888730</td>
#       <td>5.928221</td>
#       <td>0.793750</td>
#       <td>0.206250</td>
#       <td>375.485870</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.955558</td>
#       <td>5.789457</td>
#       <td>0.781473</td>
#       <td>0.218527</td>
#       <td>326.835602</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 5.928220748901367.
# Better model found at epoch 1 with valid_loss value: 5.789457321166992.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.066379</td>
#       <td>5.626930</td>
#       <td>0.766853</td>
#       <td>0.233147</td>
#       <td>277.808014</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.010132</td>
#       <td>5.610517</td>
#       <td>0.766853</td>
#       <td>0.233147</td>
#       <td>273.285370</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.838195</td>
#       <td>5.447471</td>
#       <td>0.764955</td>
#       <td>0.235045</td>
#       <td>232.170197</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.636813</td>
#       <td>5.379725</td>
#       <td>0.764732</td>
#       <td>0.235268</td>
#       <td>216.962708</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.375163</td>
#       <td>5.396468</td>
#       <td>0.761942</td>
#       <td>0.238058</td>
#       <td>220.625717</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.055846</td>
#       <td>5.464532</td>
#       <td>0.763951</td>
#       <td>0.236049</td>
#       <td>236.165390</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.706215</td>
#       <td>5.601039</td>
#       <td>0.765848</td>
#       <td>0.234152</td>
#       <td>270.707642</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.389307</td>
#       <td>5.655061</td>
#       <td>0.770871</td>
#       <td>0.229129</td>
#       <td>285.733856</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 5.626930236816406.
# Better model found at epoch 1 with valid_loss value: 5.610516548156738.
# Better model found at epoch 2 with valid_loss value: 5.447470664978027.
# Better model found at epoch 3 with valid_loss value: 5.379725456237793.
# Epoch 4: reducing lr to 0.014543553671312732
# Epoch 5: reducing lr to 0.007387099272719709
# Epoch 6: reducing lr to 0.0019974520024720393
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='96' class='' max='178' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       53.93% [96/178 00:02<00:01 0.9352]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 5.25E-03
# Min loss divided by 10: 3.63E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.482487</td>
#       <td>0.442979</td>
#       <td>0.788976</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.449805</td>
#       <td>0.437624</td>
#       <td>0.781102</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.458924</td>
#       <td>0.421881</td>
#       <td>0.804724</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.444632</td>
#       <td>0.452273</td>
#       <td>0.773228</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.422238</td>
#       <td>0.421852</td>
#       <td>0.798425</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.415045</td>
#       <td>0.419743</td>
#       <td>0.801575</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.401686</td>
#       <td>0.434850</td>
#       <td>0.779528</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.389995</td>
#       <td>0.424806</td>
#       <td>0.798425</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.398859</td>
#       <td>0.432940</td>
#       <td>0.792126</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.377071</td>
#       <td>0.428311</td>
#       <td>0.809449</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.362739</td>
#       <td>0.420856</td>
#       <td>0.814173</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.355316</td>
#       <td>0.421935</td>
#       <td>0.815748</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.4429791271686554.
# Better model found at epoch 1 with valid_loss value: 0.4376242458820343.
# Better model found at epoch 2 with valid_loss value: 0.4218812584877014.
# Epoch 3: reducing lr to 0.004174509860948693
# Better model found at epoch 4 with valid_loss value: 0.42185178399086.
# Better model found at epoch 5 with valid_loss value: 0.419743150472641.
# Epoch 6: reducing lr to 0.002715988357518396
# Epoch 7: reducing lr to 0.001940688595962141
# Epoch 8: reducing lr to 0.001187285555292827
# The accuracy is 0.8015748262405396 %.
# Gradual Unfreezing..
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.415832</td>
#       <td>0.409719</td>
#       <td>0.806299</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.440899</td>
#       <td>0.414063</td>
#       <td>0.806299</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.404962</td>
#       <td>0.421248</td>
#       <td>0.807874</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.348730</td>
#       <td>0.423733</td>
#       <td>0.798425</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.314937</td>
#       <td>0.422723</td>
#       <td>0.817323</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.263837</td>
#       <td>0.440796</td>
#       <td>0.815748</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.206386</td>
#       <td>0.437754</td>
#       <td>0.809449</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.187643</td>
#       <td>0.430317</td>
#       <td>0.823622</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.4097186326980591.
# Epoch 1: reducing lr to 0.003929700221217173
# Epoch 2: reducing lr to 0.004080267924978397
# Epoch 3: reducing lr to 0.003407342465527006
# Epoch 4: reducing lr to 0.002333572187592918
# Epoch 5: reducing lr to 0.0011879945203552133
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.401042</td>
#       <td>0.450529</td>
#       <td>0.781102</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.386500</td>
#       <td>0.394493</td>
#       <td>0.814173</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.338836</td>
#       <td>0.424793</td>
#       <td>0.790551</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.245752</td>
#       <td>0.439103</td>
#       <td>0.820472</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.155580</td>
#       <td>0.463927</td>
#       <td>0.826772</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.119091</td>
#       <td>0.444174</td>
#       <td>0.818898</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.45052871108055115.
# Better model found at epoch 1 with valid_loss value: 0.394492506980896.
# Epoch 2: reducing lr to 0.003406110977964559
# Epoch 3: reducing lr to 0.001940688595962141
# Completely Unfreezing..
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='92' class='' max='178' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       51.69% [92/178 00:03<00:03 0.7849]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 9.12E-07
# Min loss divided by 10: 2.29E-05
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.313807</td>
#       <td>0.392894</td>
#       <td>0.820472</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.322736</td>
#       <td>0.404759</td>
#       <td>0.812598</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.314602</td>
#       <td>0.396319</td>
#       <td>0.811024</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.314099</td>
#       <td>0.400208</td>
#       <td>0.812598</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.307590</td>
#       <td>0.391324</td>
#       <td>0.817323</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.313934</td>
#       <td>0.392184</td>
#       <td>0.817323</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.3928937017917633.
# Better model found at epoch 4 with valid_loss value: 0.39132386445999146.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.320392</td>
#       <td>0.402563</td>
#       <td>0.812598</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.310480</td>
#       <td>0.393419</td>
#       <td>0.818898</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.322464</td>
#       <td>0.407914</td>
#       <td>0.812598</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.324135</td>
#       <td>0.397928</td>
#       <td>0.814173</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.301305</td>
#       <td>0.396475</td>
#       <td>0.815748</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.320975</td>
#       <td>0.394514</td>
#       <td>0.817323</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.40256306529045105.
# Better model found at epoch 1 with valid_loss value: 0.3934186100959778.
# The accuracy is 0.8188976645469666 %.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       84.62% [11/13 00:09<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.532240</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.522844</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.520876</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.498483</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.466585</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.453582</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.439072</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.429973</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.429073</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.463643</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.660914</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='8' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/8 00:00<00:00]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 4.37E-05
# Min loss divided by 10: 1.32E-03
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.505103</td>
#       <td>0.637232</td>
#       <td>0.253968</td>
#       <td>0.746032</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.460104</td>
#       <td>0.538566</td>
#       <td>0.238095</td>
#       <td>0.761905</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.425718</td>
#       <td>0.451534</td>
#       <td>0.206349</td>
#       <td>0.793651</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.411494</td>
#       <td>0.422615</td>
#       <td>0.206349</td>
#       <td>0.793651</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.399093</td>
#       <td>0.408821</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.390610</td>
#       <td>0.404838</td>
#       <td>0.206349</td>
#       <td>0.793651</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.381958</td>
#       <td>0.400395</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.373064</td>
#       <td>0.398218</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.6372317671775818.
# Better model found at epoch 1 with valid_loss value: 0.5385655164718628.
# Better model found at epoch 2 with valid_loss value: 0.451534241437912.
# Better model found at epoch 3 with valid_loss value: 0.4226151704788208.
# Better model found at epoch 4 with valid_loss value: 0.4088210463523865.
# Better model found at epoch 5 with valid_loss value: 0.40483784675598145.
# Better model found at epoch 6 with valid_loss value: 0.4003947377204895.
# Better model found at epoch 7 with valid_loss value: 0.39821773767471313.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.353910</td>
#       <td>0.397082</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.345600</td>
#       <td>0.393638</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.345276</td>
#       <td>0.392281</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.348587</td>
#       <td>0.388349</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.352075</td>
#       <td>0.387805</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.349576</td>
#       <td>0.389037</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.346060</td>
#       <td>0.388990</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.345344</td>
#       <td>0.389220</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.39708203077316284.
# Better model found at epoch 1 with valid_loss value: 0.3936379849910736.
# Better model found at epoch 2 with valid_loss value: 0.3922814428806305.
# Better model found at epoch 3 with valid_loss value: 0.38834917545318604.
# Better model found at epoch 4 with valid_loss value: 0.3878052830696106.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.344603</td>
#       <td>0.387307</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.345322</td>
#       <td>0.387752</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.343742</td>
#       <td>0.388869</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.348171</td>
#       <td>0.389336</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.349950</td>
#       <td>0.389253</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.349963</td>
#       <td>0.389741</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.348867</td>
#       <td>0.389889</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.343586</td>
#       <td>0.389776</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.8253968954086304.

# %%
from AdaptTextLib.adapttext.evaluator.evaluator import Evaluator

evaluator = Evaluator()
evaluator.evaluate(ensembleModel, classifierModelFWD)
# Out:
# The accuracy is 0.8253968358039856 %.
# The error rate is 0.1746031641960144 %.
# ROC area is 0.9046653144016227
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.85        34
#            1       0.85      0.76      0.80        29
#
#     accuracy                           0.83        63
#    macro avg       0.83      0.82      0.82        63
# weighted avg       0.83      0.83      0.82        63
#
# --Mathews Correlation Coefficient--
# 0.6489198883550272
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Text</th>
#       <th>Prediction</th>
#       <th>Actual</th>
#       <th>Loss</th>
#       <th>Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos උත්තර xxunk xxunk ඇත්ත xxunk නිසි පිලිතුරු නිසි xxunk ලැබෙන විශ්වාසයි .. තෙරුවන් සරණයි</td>
#       <td>0</td>
#       <td>1</td>
#       <td>5.40</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos මෙච්චර xxunk කරල කතා කතා කරද්දි xxunk රටේ දාන්න සුදුසු නෑ</td>
#       <td>0</td>
#       <td>1</td>
#       <td>4.53</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <td>xxbos ගම්පහ තවත් එකෙක්</td>
#       <td>0</td>
#       <td>1</td>
#       <td>3.92</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <td>xxbos මුගේ වීඩියෝ එක xxunk එකට xxunk බැරිද</td>
#       <td>0</td>
#       <td>1</td>
#       <td>3.92</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <td>xxbos මොනවා කිවුවත් වැඩක් නැ මෙයාව රටේ මාධ්‍ය ඉදිරියට ගෙනත් නිසි දඩුවම් ලබා දෙන්නේ නැතිනම් ලංකාවේ xxunk වැඩකුත් නැ .. රටේ xxunk වැඩකුත් xxunk නින්දා අපහස xxunk xxunk රත්තරන් වටින xxunk ගිහින් වෙසකන් xxunk .</td>
#       <td>1</td>
#       <td>0</td>
#       <td>3.91</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <td>xxbos මොන මෝඩයෙක් මේ . මාධ්‍ය ප්‍රකාශක කෙනෙක් කිසිම දෙයක් නොදැන xxunk ඇවිත් ප්‍රකාශ කරන් xxunk දැනගෙන තමා xxunk කරන්නේ .</td>
#       <td>1</td>
#       <td>0</td>
#       <td>3.85</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <td>xxbos මේ .. ඉන්නවා හොඳ ජනාදිපති කෙනෙක් .. xxunk වැඩ xxunk තියෙනවා .. ඔයා පාඩුවේ ඉන්න ..</td>
#       <td>0</td>
#       <td>1</td>
#       <td>3.81</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <td>xxbos අම්මෝ අක්කගෙ කට</td>
#       <td>1</td>
#       <td>0</td>
#       <td>3.69</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <td>xxbos xxunk කරල දොස්තර කෙනෙක් වෙන්න බැරි උන xxunk මන්ද කෑගහන්නෙ කියලත් හිතෙනව</td>
#       <td>0</td>
#       <td>1</td>
#       <td>3.57</td>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <td>xxbos පාස්කු xxunk සාර්ථක කරගන්න xxunk xxunk කරල xxunk xxunk අවධානය යොමු xxunk xxunk විදියට ආරක්ෂක අංශ නොමග යවපු xxunk තමා මු</td>
#       <td>0</td>
#       <td>1</td>
#       <td>3.26</td>
#       <td>0.04</td>
#     </tr>
#   </tbody>
# </table>
