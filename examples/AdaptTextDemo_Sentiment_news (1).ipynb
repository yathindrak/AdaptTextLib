# %%
# !apt-get update
# !apt install -y git
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Fetched 252 kB in 1s (269 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   git-man libasn1-8-heimdal libcurl3-gnutls liberror-perl libexpat1
#   libgdbm-compat4 libgdbm5 libgssapi3-heimdal libhcrypto4-heimdal
#   libheimbase1-heimdal libheimntlm0-heimdal libhx509-5-heimdal
#   libkrb5-26-heimdal libldap-2.4-2 libldap-common libnghttp2-14 libperl5.26
#   libpsl5 libroken18-heimdal librtmp1 libsasl2-2 libsasl2-modules
#   libsasl2-modules-db libsqlite3-0 libwind0-heimdal netbase patch perl
#   perl-modules-5.26 publicsuffix
# Suggested packages:
#   gettext-base git-daemon-run | git-daemon-sysvinit git-doc git-el git-email
#   git-gui gitk gitweb git-cvs git-mediawiki git-svn gdbm-l10n
#   libsasl2-modules-gssapi-mit | libsasl2-modules-gssapi-heimdal
#   libsasl2-modules-ldap libsasl2-modules-otp libsasl2-modules-sql ed
#   diffutils-doc perl-doc libterm-readline-gnu-perl
#   | libterm-readline-perl-perl make
# The following NEW packages will be installed:
#   git git-man libasn1-8-heimdal libcurl3-gnutls liberror-perl libexpat1
#   libgdbm-compat4 libgdbm5 libgssapi3-heimdal libhcrypto4-heimdal
#   libheimbase1-heimdal libheimntlm0-heimdal libhx509-5-heimdal
#   libkrb5-26-heimdal libldap-2.4-2 libldap-common libnghttp2-14 libperl5.26
#   libpsl5 libroken18-heimdal librtmp1 libsasl2-2 libsasl2-modules
#   libsasl2-modules-db libsqlite3-0 libwind0-heimdal netbase patch perl
#   perl-modules-5.26 publicsuffix
# 0 upgraded, 31 newly installed, 0 to remove and 3 not upgraded.
# Need to get 13.5 MB of archives.
# After this operation, 82.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 perl-modules-5.26 all 5.26.1-6ubuntu0.5 [2762 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdbm5 amd64 1.14.1-6 [26.0 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdbm-compat4 amd64 1.14.1-6 [6084 B]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libperl5.26 amd64 5.26.1-6ubuntu0.5 [3534 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 perl amd64 5.26.1-6ubuntu0.5 [201 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libexpat1 amd64 2.2.5-3ubuntu0.2 [80.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsqlite3-0 amd64 3.22.0-1ubuntu0.4 [499 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 netbase all 5.4 [12.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpsl5 amd64 0.19.1-5build1 [41.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 publicsuffix all 20180223.1310-1 [97.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libroken18-heimdal amd64 7.5.0+dfsg-1 [41.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libasn1-8-heimdal amd64 7.5.0+dfsg-1 [175 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libheimbase1-heimdal amd64 7.5.0+dfsg-1 [29.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhcrypto4-heimdal amd64 7.5.0+dfsg-1 [85.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwind0-heimdal amd64 7.5.0+dfsg-1 [47.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhx509-5-heimdal amd64 7.5.0+dfsg-1 [107 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libkrb5-26-heimdal amd64 7.5.0+dfsg-1 [206 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libheimntlm0-heimdal amd64 7.5.0+dfsg-1 [14.8 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgssapi3-heimdal amd64 7.5.0+dfsg-1 [96.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules-db amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [15.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-2 amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [49.2 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-common all 2.4.45+dfsg-1ubuntu1.10 [15.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-2.4-2 amd64 2.4.45+dfsg-1ubuntu1.10 [154 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnghttp2-14 amd64 1.30.0-1ubuntu1 [77.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 librtmp1 amd64 2.4+20151223.gitfa8646d.1-1 [54.2 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcurl3-gnutls amd64 7.58.0-2ubuntu3.12 [212 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 liberror-perl all 0.17025-1 [22.8 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 git-man all 1:2.17.1-1ubuntu0.8 [804 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 git amd64 1:2.17.1-1ubuntu0.8 [3916 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [48.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 patch amd64 2.7.6-2ubuntu1.1 [102 kB]
# Fetched 13.5 MB in 2s (5868 kB/s)0m
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package perl-modules-5.26.
# (Reading database ... 6773 files and directories currently installed.)
# Preparing to unpack .../00-perl-modules-5.26_5.26.1-6ubuntu0.5_all.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking perl-modules-5.26 (5.26.1-6ubuntu0.5) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libgdbm5:amd64.
# Preparing to unpack .../01-libgdbm5_1.14.1-6_amd64.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking libgdbm5:amd64 (1.14.1-6) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libgdbm-compat4:amd64.
# Preparing to unpack .../02-libgdbm-compat4_1.14.1-6_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libgdbm-compat4:amd64 (1.14.1-6) ...
# 7Progress: [  5%] [##........................................................] 8Selecting previously unselected package libperl5.26:amd64.
# Preparing to unpack .../03-libperl5.26_5.26.1-6ubuntu0.5_amd64.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking libperl5.26:amd64 (5.26.1-6ubuntu0.5) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package perl.
# Preparing to unpack .../04-perl_5.26.1-6ubuntu0.5_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking perl (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package libexpat1:amd64.
# Preparing to unpack .../05-libexpat1_2.2.5-3ubuntu0.2_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libexpat1:amd64 (2.2.5-3ubuntu0.2) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libsqlite3-0:amd64.
# Preparing to unpack .../06-libsqlite3-0_3.22.0-1ubuntu0.4_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libsqlite3-0:amd64 (3.22.0-1ubuntu0.4) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package netbase.
# Preparing to unpack .../07-netbase_5.4_all.deb ...
# 7Progress: [ 14%] [########..................................................] 8Unpacking netbase (5.4) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libpsl5:amd64.
# Preparing to unpack .../08-libpsl5_0.19.1-5build1_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking libpsl5:amd64 (0.19.1-5build1) ...
# 7Progress: [ 17%] [##########................................................] 8Selecting previously unselected package publicsuffix.
# Preparing to unpack .../09-publicsuffix_20180223.1310-1_all.deb ...
# Unpacking publicsuffix (20180223.1310-1) ...
# 7Progress: [ 19%] [##########................................................] 87Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libroken18-heimdal:amd64.
# Preparing to unpack .../10-libroken18-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libroken18-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 21%] [###########...............................................] 87Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libasn1-8-heimdal:amd64.
# Preparing to unpack .../11-libasn1-8-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libasn1-8-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 22%] [#############.............................................] 87Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libheimbase1-heimdal:amd64.
# Preparing to unpack .../12-libheimbase1-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libheimbase1-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 24%] [##############............................................] 87Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libhcrypto4-heimdal:amd64.
# Preparing to unpack .../13-libhcrypto4-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libhcrypto4-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libwind0-heimdal:amd64.
# Preparing to unpack .../14-libwind0-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 28%] [###############...........................................] 8Unpacking libwind0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libhx509-5-heimdal:amd64.
# Preparing to unpack .../15-libhx509-5-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libhx509-5-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libkrb5-26-heimdal:amd64.
# Preparing to unpack .../16-libkrb5-26-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 31%] [##################........................................] 8Unpacking libkrb5-26-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libheimntlm0-heimdal:amd64.
# Preparing to unpack .../17-libheimntlm0-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking libheimntlm0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libgssapi3-heimdal:amd64.
# Preparing to unpack .../18-libgssapi3-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libgssapi3-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libsasl2-modules-db:amd64.
# Preparing to unpack .../19-libsasl2-modules-db_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package libsasl2-2:amd64.
# Preparing to unpack .../20-libsasl2-2_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package libldap-common.
# Preparing to unpack .../21-libldap-common_2.4.45+dfsg-1ubuntu1.10_all.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package libldap-2.4-2:amd64.
# Preparing to unpack .../22-libldap-2.4-2_2.4.45+dfsg-1ubuntu1.10_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 44%] [#########################.................................] 87Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libnghttp2-14:amd64.
# Preparing to unpack .../23-libnghttp2-14_1.30.0-1ubuntu1_amd64.deb ...
# Unpacking libnghttp2-14:amd64 (1.30.0-1ubuntu1) ...
# 7Progress: [ 46%] [##########################................................] 87Progress: [ 46%] [##########################................................] 8Selecting previously unselected package librtmp1:amd64.
# Preparing to unpack .../24-librtmp1_2.4+20151223.gitfa8646d.1-1_amd64.deb ...
# Unpacking librtmp1:amd64 (2.4+20151223.gitfa8646d.1-1) ...
# 7Progress: [ 47%] [###########################...............................] 87Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package libcurl3-gnutls:amd64.
# Preparing to unpack .../25-libcurl3-gnutls_7.58.0-2ubuntu3.12_amd64.deb ...
# Unpacking libcurl3-gnutls:amd64 (7.58.0-2ubuntu3.12) ...
# 7Progress: [ 49%] [############################..............................] 87Progress: [ 50%] [#############################.............................] 8Selecting previously unselected package liberror-perl.
# Preparing to unpack .../26-liberror-perl_0.17025-1_all.deb ...
# Unpacking liberror-perl (0.17025-1) ...
# 7Progress: [ 51%] [#############################.............................] 8Selecting previously unselected package git-man.
# Preparing to unpack .../27-git-man_1%3a2.17.1-1ubuntu0.8_all.deb ...
# 7Progress: [ 53%] [##############################............................] 8Unpacking git-man (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 53%] [##############################............................] 8Selecting previously unselected package git.
# Preparing to unpack .../28-git_1%3a2.17.1-1ubuntu0.8_amd64.deb ...
# 7Progress: [ 54%] [###############################...........................] 8Unpacking git (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 55%] [###############################...........................] 8Selecting previously unselected package libsasl2-modules:amd64.
# Preparing to unpack .../29-libsasl2-modules_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 56%] [################################..........................] 8Unpacking libsasl2-modules:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 57%] [#################################.........................] 8Selecting previously unselected package patch.
# Preparing to unpack .../30-patch_2.7.6-2ubuntu1.1_amd64.deb ...
# 7Progress: [ 58%] [#################################.........................] 8Unpacking patch (2.7.6-2ubuntu1.1) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up git-man (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libexpat1:amd64 (2.2.5-3ubuntu0.2) ...
# 7Progress: [ 62%] [###################################.......................] 87Progress: [ 62%] [####################################......................] 8Setting up libnghttp2-14:amd64 (1.30.0-1ubuntu1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libpsl5:amd64 (0.19.1-5build1) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 66%] [######################################....................] 8Setting up libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 67%] [#######################################...................] 8Setting up libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 69%] [#######################################...................] 8Setting up libroken18-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up librtmp1:amd64 (2.4+20151223.gitfa8646d.1-1) ...
# 7Progress: [ 71%] [########################################..................] 87Progress: [ 71%] [#########################################.................] 8Setting up perl-modules-5.26 (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 72%] [##########################################................] 8Setting up libgdbm5:amd64 (1.14.1-6) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up patch (2.7.6-2ubuntu1.1) ...
# 7Progress: [ 74%] [###########################################...............] 87Progress: [ 75%] [###########################################...............] 8Setting up publicsuffix (20180223.1310-1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libheimbase1-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 78%] [############################################..............] 8Setting up libsqlite3-0:amd64 (3.22.0-1ubuntu0.4) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libgdbm-compat4:amd64 (1.14.1-6) ...
# 7Progress: [ 79%] [##############################################............] 87Progress: [ 80%] [##############################################............] 8Setting up libsasl2-modules:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up netbase (5.4) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libwind0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libasn1-8-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 85%] [#################################################.........] 87Progress: [ 85%] [#################################################.........] 8Setting up libhcrypto4-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libhx509-5-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libperl5.26:amd64 (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 89%] [###################################################.......] 8Setting up libkrb5-26-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libheimntlm0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up perl (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libgssapi3-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 94%] [######################################################....] 87Progress: [ 94%] [######################################################....] 8Setting up liberror-perl (0.17025-1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libcurl3-gnutls:amd64 (7.58.0-2ubuntu3.12) ...
# 7Progress: [ 97%] [########################################################..] 87Progress: [ 98%] [########################################################..] 8Setting up git (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for libc-bin (2.27-3ubuntu1.4) ...
#
# 78

# %%
# !git clone https://gitlab.com/AdaptText/AdaptTextLib.git
# Out:
# Cloning into 'AdaptTextLib'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 635 (delta 0), reused 0 (delta 0), pack-reused 632
# Receiving objects: 100% (635/635), 720.83 KiB | 4.12 MiB/s, done.
# Resolving deltas: 100% (434/434), done.

# %%
# !cd AdaptTextLib && bash setup.sh
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease0m
# Hit:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 3 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Collecting wikiextractor==0.01
#   Downloading wikiextractor-0.1.tar.gz (36 kB)
# Collecting sentencepiece==0.1.95
#   Downloading sentencepiece-0.1.95-cp38-cp38-manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 6.1 MB/s eta 0:00:01
# Collecting ninja==1.10.0
#   Downloading ninja-1.10.0-py3-none-manylinux1_x86_64.whl (102 kB)
#      |████████████████████████████████| 102 kB 32.4 MB/s eta 0:00:01
# Collecting emoji==1.2.0
#   Downloading emoji-1.2.0-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 27.9 MB/s eta 0:00:01
# Collecting flask==1.1.2
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 6.5 MB/s  eta 0:00:01
# Collecting gunicorn==20.0.4
#   Downloading gunicorn-20.0.4-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 10.5 MB/s eta 0:00:01
# Requirement already satisfied: torch in /opt/conda/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (1.8.1)
# Collecting python-dotenv==0.15.0
#   Downloading python_dotenv-0.15.0-py2.py3-none-any.whl (18 kB)
# Collecting dropbox==11.2.0
#   Downloading dropbox-11.2.0-py3-none-any.whl (555 kB)
#      |████████████████████████████████| 555 kB 24.7 MB/s eta 0:00:01
# Collecting dataclasses==0.6
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting spacy==2.3.5
#   Downloading spacy-2.3.5-cp38-cp38-manylinux2014_x86_64.whl (10.5 MB)
#      |████████████████████████████████| 10.5 MB 27.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (1.19.2)
# Collecting matplotlib
#   Downloading matplotlib-3.4.0-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 26.8 MB/s eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.1-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      |████████████████████████████████| 24.9 MB 25.7 MB/s eta 0:00:01
# Collecting fastprogress
#   Downloading fastprogress-1.0.0-py3-none-any.whl (12 kB)
# Collecting scipy==1.6.1
#   Downloading scipy-1.6.1-cp38-cp38-manylinux1_x86_64.whl (27.3 MB)
#      |████████████████████████████████| 27.3 MB 344 kB/s  eta 0:00:01
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting pandas
#   Downloading pandas-1.2.3-cp38-cp38-manylinux1_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 26.0 MB/s eta 0:00:01
# Collecting Werkzeug>=0.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 28.2 MB/s eta 0:00:01
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/conda/lib/python3.8/site-packages (from flask==1.1.2->-r requirements.txt (line 5)) (2.11.3)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 2.1 MB/s  eta 0:00:01
# Requirement already satisfied: setuptools>=3.0 in /opt/conda/lib/python3.8/site-packages (from gunicorn==20.0.4->-r requirements.txt (line 6)) (50.3.1.post20201107)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.8/site-packages (from torch->-r requirements.txt (line 8)) (3.7.4.3)
# Collecting stone>=2.*
#   Downloading stone-3.2.1-py3-none-any.whl (160 kB)
#      |████████████████████████████████| 160 kB 27.3 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.16.2 in /opt/conda/lib/python3.8/site-packages (from dropbox==11.2.0->-r requirements.txt (line 10)) (2.24.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.8/site-packages (from dropbox==11.2.0->-r requirements.txt (line 10)) (1.15.0)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.5-cp38-cp38-manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 2.8 MB/s eta 0:00:01
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.5-cp38-cp38-manylinux2014_x86_64.whl (186 kB)
#      |████████████████████████████████| 186 kB 28.7 MB/s eta 0:00:01
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp38-cp38-manylinux2014_x86_64.whl (35 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp38-cp38-manylinux2014_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 28.6 MB/s eta 0:00:01
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.8/site-packages (from spacy==2.3.5->-r requirements.txt (line 12)) (4.51.0)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp38-cp38-manylinux2014_x86_64.whl (20 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp38-cp38-manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 26.4 MB/s eta 0:00:01
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (8.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (2.4.7)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp38-cp38-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 3.2 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 24.6 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 20)) (2021.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from Jinja2>=2.10.1->flask==1.1.2->-r requirements.txt (line 5)) (1.1.1)
# Collecting ply>=3.4
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 10.9 MB/s eta 0:00:01
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (1.25.11)
# Building wheels for collected packages: wikiextractor, sklearn
#   Building wheel for wikiextractor (setup.py) ... done
#   Created wheel for wikiextractor: filename=wikiextractor-0.1-py3-none-any.whl size=38819 sha256=74110e005351cd287217bca6232fd04e75a192e650edb1d405522a739fb3c7f8
#   Stored in directory: /root/.cache/pip/wheels/98/50/4b/5a06f4f998b52f6b828af95aa4e1b3efb784b3210c970bcaf3
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=a81037a49fa0654cb331e4cff076b4bb2c011145d077870dffe1997c3d0d0845
#   Stored in directory: /root/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built wikiextractor sklearn
# Installing collected packages: wikiextractor, sentencepiece, ninja, emoji, Werkzeug, itsdangerous, click, flask, gunicorn, python-dotenv, ply, stone, dropbox, dataclasses, cymem, murmurhash, preshed, plac, wasabi, blis, catalogue, srsly, thinc, spacy, kiwisolver, cycler, matplotlib, threadpoolctl, joblib, scipy, scikit-learn, fastprogress, sklearn, pandas
# Successfully installed Werkzeug-1.0.1 blis-0.7.4 catalogue-1.0.0 click-7.1.2 cycler-0.10.0 cymem-2.0.5 dataclasses-0.6 dropbox-11.2.0 emoji-1.2.0 fastprogress-1.0.0 flask-1.1.2 gunicorn-20.0.4 itsdangerous-1.1.0 joblib-1.0.1 kiwisolver-1.3.1 matplotlib-3.4.0 murmurhash-1.0.5 ninja-1.10.0 pandas-1.2.3 plac-1.1.3 ply-3.11 preshed-3.0.5 python-dotenv-0.15.0 scikit-learn-0.24.1 scipy-1.6.1 sentencepiece-0.1.95 sklearn-0.0 spacy-2.3.5 srsly-1.0.5 stone-3.2.1 thinc-7.4.5 threadpoolctl-2.1.0 wasabi-0.8.2 wikiextractor-0.1
# Cloning into 'fastai1'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (128/128), done.
# remote: Total 150 (delta 26), reused 131 (delta 18), pack-reused 0
# Receiving objects: 100% (150/150), 207.34 KiB | 2.36 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# Cloning into 'Best-Deep-Learning-Optimizers'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 190 (delta 4), reused 1 (delta 0), pack-reused 178
# Receiving objects: 100% (190/190), 849.15 KiB | 2.79 MiB/s, done.
# Resolving deltas: 100% (85/85), done.

# %%
from AdaptTextLib.adapttext.adapt_text import AdaptText

lang = 'si'
app_root = "/storage"
bs = 128
splitting_ratio = 0.1
adapttext = AdaptText(lang, app_root, bs, splitting_ratio)

# %%
adapttext.prepare_pretrained_lm("full_si_dedup.zip")

# %%
import pandas as pd

pd.set_option('display.max_colwidth', -1)
# path_to_csv="sinhala-hate-speech-dataset.csv"
path_to_csv="sentiment-news.csv"
# path_to_csv="small_sin.csv"
df = pd.read_csv(path_to_csv)

text_name = "comment"
label_name = "label"

# print(df.head())

classifierModelFWD, classifierModelBWD, ensembleModel, classes = adapttext.build_classifier(df, text_name, label_name, grad_unfreeze=True)
# Out:
# 2    7665
# 4    3080
# 3    2403
# 5    1911
# Name: label, dtype: int64
# 2    6898
# 4    2772
# 3    2163
# 5    1720
# Name: label, dtype: int64
# 2    6898
# 4    2772
# 3    2163
# 5    1720
# Name: label, dtype: int64
# Training Forward model...
# [PosixPath('/storage/data/siwiki/models/si_wt'), PosixPath('/storage/data/siwiki/models/si_wt_vocab')]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 00:05<00:05]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.963560</td>
#       <td>#na#</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='33' class='' max='65' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.77% [33/65 00:02<00:02 13.9986]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 5.75E-02
# Min loss divided by 10: 2.09E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.709113</td>
#       <td>6.007401</td>
#       <td>0.784311</td>
#       <td>0.215689</td>
#       <td>406.425079</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.928469</td>
#       <td>5.824746</td>
#       <td>0.773565</td>
#       <td>0.226435</td>
#       <td>338.575012</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 6.0074005126953125.
# Better model found at epoch 1 with valid_loss value: 5.8247456550598145.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.196566</td>
#       <td>5.876499</td>
#       <td>0.781760</td>
#       <td>0.218240</td>
#       <td>356.558624</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.654770</td>
#       <td>6.123000</td>
#       <td>0.789286</td>
#       <td>0.210714</td>
#       <td>456.231201</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.843017</td>
#       <td>0.156983</td>
#       <td>nan</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.843017</td>
#       <td>0.156983</td>
#       <td>nan</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.843017</td>
#       <td>0.156983</td>
#       <td>nan</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.843017</td>
#       <td>0.156983</td>
#       <td>nan</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.843017</td>
#       <td>0.156983</td>
#       <td>nan</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.843017</td>
#       <td>0.156983</td>
#       <td>nan</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 5.876498699188232.
# Epoch 1: reducing lr to 0.04307477259013208
# Epoch 2: reducing lr to 0.044743529238019275
# Epoch 3: reducing lr to 0.03736886945940487
# Epoch 4: reducing lr to 0.02559483249977826
# Epoch 5: reducing lr to 0.013030768245744551
# Epoch 6: reducing lr to 0.0035282107162723448
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='96' class='' max='423' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       22.70% [96/423 00:03<00:10 2.2183]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.92E-02
# Min loss divided by 10: 1.00E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.028220</td>
#       <td>0.991385</td>
#       <td>0.604914</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.007903</td>
#       <td>0.977525</td>
#       <td>0.610890</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.029400</td>
#       <td>0.991289</td>
#       <td>0.614874</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.029540</td>
#       <td>1.004793</td>
#       <td>0.604914</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.983946</td>
#       <td>1.036800</td>
#       <td>0.570385</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.016255</td>
#       <td>0.968866</td>
#       <td>0.612218</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.991670</td>
#       <td>0.981284</td>
#       <td>0.612218</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.993325</td>
#       <td>0.981456</td>
#       <td>0.610226</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.982768</td>
#       <td>0.975377</td>
#       <td>0.622178</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.977274</td>
#       <td>0.972507</td>
#       <td>0.616202</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.936817</td>
#       <td>0.954938</td>
#       <td>0.624834</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.922673</td>
#       <td>0.957054</td>
#       <td>0.627490</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.9913849830627441.
# Better model found at epoch 1 with valid_loss value: 0.9775246977806091.
# Epoch 2: reducing lr to 0.0518055240206335
# Epoch 3: reducing lr to 0.05503460769140054
# Epoch 4: reducing lr to 0.05163082336711027
# Better model found at epoch 5 with valid_loss value: 0.968866229057312.
# Epoch 6: reducing lr to 0.035819015494104434
# Epoch 7: reducing lr to 0.025596041418327293
# Epoch 8: reducing lr to 0.015660132618726626
# Epoch 9: reducing lr to 0.007384342224969891
# Better model found at epoch 10 with valid_loss value: 0.9549378156661987.
# The accuracy is 0.6248340010643005 %.
# Gradual Unfreezing..
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.990364</td>
#       <td>0.955020</td>
#       <td>0.616202</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.024342</td>
#       <td>0.970205</td>
#       <td>0.624170</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.076866</td>
#       <td>4.511111</td>
#       <td>0.559097</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.968689</td>
#       <td>1.020070</td>
#       <td>0.613546</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.965989</td>
#       <td>1.227872</td>
#       <td>0.632802</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.877675</td>
#       <td>0.955995</td>
#       <td>0.623506</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.739220</td>
#       <td>1.015545</td>
#       <td>0.623506</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.537914</td>
#       <td>1.217633</td>
#       <td>0.612218</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.9550200700759888.
# Epoch 1: reducing lr to 0.05179411631241975
# Epoch 2: reducing lr to 0.05379138875696391
# Epoch 3: reducing lr to 0.04492316358959302
# Epoch 4: reducing lr to 0.030767849581755238
# Epoch 5: reducing lr to 0.01566406757100545
# Epoch 6: reducing lr to 0.004241144983174172
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.150362</td>
#       <td>6.100110</td>
#       <td>0.489376</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.228264</td>
#       <td>9.111502</td>
#       <td>0.497344</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.234957</td>
#       <td>1.441475</td>
#       <td>0.508632</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.245910</td>
#       <td>1.539435</td>
#       <td>0.458167</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.194438</td>
#       <td>1.617051</td>
#       <td>0.533865</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.072794</td>
#       <td>1.177175</td>
#       <td>0.565737</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 6.100110054016113.
# Epoch 1: reducing lr to 0.05503460769140054
# Better model found at epoch 2 with valid_loss value: 1.44147527217865.
# Epoch 3: reducing lr to 0.025596041418327293
# Epoch 4: reducing lr to 0.007384342224969891
# Better model found at epoch 5 with valid_loss value: 1.1771751642227173.
# Completely Unfreezing..
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='93' class='' max='423' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.99% [93/423 00:06<00:22 2.2982]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-07
# Min loss divided by 10: 1.32E-07
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.071273</td>
#       <td>1.224794</td>
#       <td>0.540505</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.059644</td>
#       <td>1.213568</td>
#       <td>0.542497</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.056379</td>
#       <td>1.166555</td>
#       <td>0.561753</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.070747</td>
#       <td>1.271974</td>
#       <td>0.535857</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.053033</td>
#       <td>1.187213</td>
#       <td>0.552457</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.071358</td>
#       <td>1.196650</td>
#       <td>0.550465</td>
#       <td>00:30</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.2247941493988037.
# Better model found at epoch 1 with valid_loss value: 1.2135682106018066.
# Better model found at epoch 2 with valid_loss value: 1.1665549278259277.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.060643</td>
#       <td>1.182209</td>
#       <td>0.563745</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.077320</td>
#       <td>1.164884</td>
#       <td>0.568393</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.058672</td>
#       <td>1.200505</td>
#       <td>0.555113</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.078317</td>
#       <td>1.171877</td>
#       <td>0.567065</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.076708</td>
#       <td>1.156722</td>
#       <td>0.571713</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.069684</td>
#       <td>1.242577</td>
#       <td>0.539841</td>
#       <td>00:29</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.1822090148925781.
# Better model found at epoch 1 with valid_loss value: 1.1648842096328735.
# Better model found at epoch 4 with valid_loss value: 1.156722068786621.
# The accuracy is 0.5717131495475769 %.
# reverting back to initial model...
# The new accuracy is 0.6248340010643005 %.
# Training Backward model...
# [PosixPath('/storage/data/siwiki/models/si_wt_bwd'), PosixPath('/storage/data/siwiki/models/si_wt_vocab_bwd')]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 00:05<00:05]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.935626</td>
#       <td>#na#</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='33' class='' max='65' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.77% [33/65 00:02<00:02 13.8901]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 5.75E-02
# Min loss divided by 10: 2.51E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.692476</td>
#       <td>5.974579</td>
#       <td>0.807876</td>
#       <td>0.192124</td>
#       <td>393.302246</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.897824</td>
#       <td>5.810554</td>
#       <td>0.799649</td>
#       <td>0.200351</td>
#       <td>333.803833</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 5.974578857421875.
# Better model found at epoch 1 with valid_loss value: 5.810554027557373.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.172213</td>
#       <td>5.832046</td>
#       <td>0.798150</td>
#       <td>0.201849</td>
#       <td>341.055634</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.640322</td>
#       <td>6.166153</td>
#       <td>0.814828</td>
#       <td>0.185172</td>
#       <td>476.350067</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.843176</td>
#       <td>0.156824</td>
#       <td>nan</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.843176</td>
#       <td>0.156824</td>
#       <td>nan</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.843176</td>
#       <td>0.156824</td>
#       <td>nan</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.843176</td>
#       <td>0.156824</td>
#       <td>nan</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.843176</td>
#       <td>0.156824</td>
#       <td>nan</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.843176</td>
#       <td>0.156824</td>
#       <td>nan</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 5.832045555114746.
# Epoch 1: reducing lr to 0.04307477259013208
# Epoch 2: reducing lr to 0.044743529238019275
# Epoch 3: reducing lr to 0.03736886945940487
# Epoch 4: reducing lr to 0.02559483249977826
# Epoch 5: reducing lr to 0.013030768245744551
# Epoch 6: reducing lr to 0.0035282107162723448
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='97' class='' max='423' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       22.93% [97/423 00:03<00:10 3.1669]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-07
# Min loss divided by 10: 3.63E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.436232</td>
#       <td>1.452190</td>
#       <td>0.278884</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.431610</td>
#       <td>1.443671</td>
#       <td>0.288181</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.427137</td>
#       <td>1.424578</td>
#       <td>0.301461</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.421794</td>
#       <td>1.409802</td>
#       <td>0.312085</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.409343</td>
#       <td>1.417485</td>
#       <td>0.309429</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.402112</td>
#       <td>1.385687</td>
#       <td>0.307437</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.412027</td>
#       <td>1.392030</td>
#       <td>0.334661</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.407020</td>
#       <td>1.384530</td>
#       <td>0.338645</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.387735</td>
#       <td>1.377925</td>
#       <td>0.333997</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.388291</td>
#       <td>1.390317</td>
#       <td>0.332005</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.381262</td>
#       <td>1.379978</td>
#       <td>0.329349</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.397258</td>
#       <td>1.370447</td>
#       <td>0.347942</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.4521903991699219.
# Better model found at epoch 1 with valid_loss value: 1.4436709880828857.
# Better model found at epoch 2 with valid_loss value: 1.4245777130126953.
# Better model found at epoch 3 with valid_loss value: 1.4098018407821655.
# Better model found at epoch 5 with valid_loss value: 1.3856873512268066.
# Better model found at epoch 7 with valid_loss value: 1.384529948234558.
# Better model found at epoch 8 with valid_loss value: 1.3779247999191284.
# Better model found at epoch 11 with valid_loss value: 1.3704465627670288.
# The accuracy is 0.3479415774345398 %.
# Gradual Unfreezing..
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.410786</td>
#       <td>1.377073</td>
#       <td>0.335989</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.372368</td>
#       <td>1.354408</td>
#       <td>0.345286</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.385544</td>
#       <td>1.348248</td>
#       <td>0.362550</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.377924</td>
#       <td>1.352168</td>
#       <td>0.357238</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.377205</td>
#       <td>1.360392</td>
#       <td>0.347942</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.361102</td>
#       <td>1.326885</td>
#       <td>0.359894</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.368272</td>
#       <td>1.352989</td>
#       <td>0.351262</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.357858</td>
#       <td>1.350518</td>
#       <td>0.355910</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.3770729303359985.
# Better model found at epoch 1 with valid_loss value: 1.354407548904419.
# Better model found at epoch 2 with valid_loss value: 1.3482484817504883.
# Better model found at epoch 5 with valid_loss value: 1.3268848657608032.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.358198</td>
#       <td>1.341559</td>
#       <td>0.366534</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.346632</td>
#       <td>1.317322</td>
#       <td>0.373838</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.353703</td>
#       <td>1.311277</td>
#       <td>0.382470</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.329277</td>
#       <td>1.307056</td>
#       <td>0.387118</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.325250</td>
#       <td>1.323459</td>
#       <td>0.369190</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.347072</td>
#       <td>1.312664</td>
#       <td>0.387118</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.3415590524673462.
# Better model found at epoch 1 with valid_loss value: 1.3173221349716187.
# Better model found at epoch 2 with valid_loss value: 1.3112765550613403.
# Better model found at epoch 3 with valid_loss value: 1.3070560693740845.
# Completely Unfreezing..
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='97' class='' max='423' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       22.93% [97/423 00:06<00:22 3.9074]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 7.59E-03
# Min loss divided by 10: 1.20E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.980366</td>
#       <td>0.947935</td>
#       <td>0.629482</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.958786</td>
#       <td>0.972242</td>
#       <td>0.614874</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.844519</td>
#       <td>1.010538</td>
#       <td>0.622178</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.621569</td>
#       <td>1.221285</td>
#       <td>0.608234</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.320999</td>
#       <td>1.457395</td>
#       <td>0.590969</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.149149</td>
#       <td>1.582131</td>
#       <td>0.586321</td>
#       <td>00:30</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.9479354619979858.
# Epoch 1: reducing lr to 0.006034424736691472
# Epoch 2: reducing lr to 0.004924977855721711
# Epoch 3: reducing lr to 0.0028065501322773762
# Epoch 4: reducing lr to 0.0008096770242538939
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.778865</td>
#       <td>0.952783</td>
#       <td>0.622842</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.795302</td>
#       <td>0.961750</td>
#       <td>0.636122</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.522882</td>
#       <td>1.141134</td>
#       <td>0.610890</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.218582</td>
#       <td>1.453374</td>
#       <td>0.617530</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.074235</td>
#       <td>1.723076</td>
#       <td>0.604914</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.040300</td>
#       <td>1.775531</td>
#       <td>0.614210</td>
#       <td>00:29</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.9527831077575684.
# Epoch 1: reducing lr to 0.003017212368345736
# Epoch 2: reducing lr to 0.0024624889278608555
# Epoch 3: reducing lr to 0.0014032750661386881
# The accuracy is 0.6228419542312622 %.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.105685</td>
#       <td>0.993176</td>
#       <td>0.326667</td>
#       <td>0.673333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.040607</td>
#       <td>1.010592</td>
#       <td>0.373333</td>
#       <td>0.626667</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.011259</td>
#       <td>0.979348</td>
#       <td>0.306667</td>
#       <td>0.693333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.006765</td>
#       <td>0.951995</td>
#       <td>0.353333</td>
#       <td>0.646667</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.984412</td>
#       <td>0.911732</td>
#       <td>0.366667</td>
#       <td>0.633333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.952242</td>
#       <td>0.876913</td>
#       <td>0.340000</td>
#       <td>0.660000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.921358</td>
#       <td>0.856848</td>
#       <td>0.313333</td>
#       <td>0.686667</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.887489</td>
#       <td>0.861795</td>
#       <td>0.306667</td>
#       <td>0.693333</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.9931764602661133.
# Epoch 1: reducing lr to 0.007525017651368435
# Better model found at epoch 2 with valid_loss value: 0.9793476462364197.
# Better model found at epoch 3 with valid_loss value: 0.9519951343536377.
# Better model found at epoch 4 with valid_loss value: 0.9117319583892822.
# Better model found at epoch 5 with valid_loss value: 0.8769130706787109.
# Better model found at epoch 6 with valid_loss value: 0.8568483591079712.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.833543</td>
#       <td>0.856418</td>
#       <td>0.306667</td>
#       <td>0.693333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.844239</td>
#       <td>0.859572</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.844201</td>
#       <td>0.869223</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.842010</td>
#       <td>0.873866</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.838735</td>
#       <td>0.868703</td>
#       <td>0.313333</td>
#       <td>0.686667</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.835574</td>
#       <td>0.866471</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.831590</td>
#       <td>0.868216</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.829961</td>
#       <td>0.866635</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.8564184308052063.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [4/5 00:05<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.843331</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.841740</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.848304</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.148158</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='21' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       28.57% [6/21 00:01<00:02 2.6541]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 2.75E-04
# Min loss divided by 10: 6.31E-08
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.836005</td>
#       <td>0.859236</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.834784</td>
#       <td>0.858601</td>
#       <td>0.306667</td>
#       <td>0.693333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.839919</td>
#       <td>0.869166</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.836808</td>
#       <td>0.878028</td>
#       <td>0.326667</td>
#       <td>0.673333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.839982</td>
#       <td>0.870552</td>
#       <td>0.326667</td>
#       <td>0.673333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.836316</td>
#       <td>0.869937</td>
#       <td>0.333333</td>
#       <td>0.666667</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.833368</td>
#       <td>0.874664</td>
#       <td>0.326667</td>
#       <td>0.673333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.829947</td>
#       <td>0.873101</td>
#       <td>0.326667</td>
#       <td>0.673333</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.859235942363739.
# Better model found at epoch 1 with valid_loss value: 0.8586010932922363.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.832224</td>
#       <td>0.864485</td>
#       <td>0.306667</td>
#       <td>0.693333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.834619</td>
#       <td>0.865468</td>
#       <td>0.306667</td>
#       <td>0.693333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.830856</td>
#       <td>0.863057</td>
#       <td>0.306667</td>
#       <td>0.693333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.832250</td>
#       <td>0.865466</td>
#       <td>0.313333</td>
#       <td>0.686667</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.835850</td>
#       <td>0.867158</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.837024</td>
#       <td>0.866379</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.834925</td>
#       <td>0.866192</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.831753</td>
#       <td>0.866170</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.8644846677780151.
# Better model found at epoch 2 with valid_loss value: 0.8630572557449341.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.826230</td>
#       <td>0.864863</td>
#       <td>0.313333</td>
#       <td>0.686667</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.830611</td>
#       <td>0.864101</td>
#       <td>0.300000</td>
#       <td>0.700000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.835462</td>
#       <td>0.866003</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.833288</td>
#       <td>0.871081</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.830720</td>
#       <td>0.866599</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.829168</td>
#       <td>0.867719</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.829574</td>
#       <td>0.866772</td>
#       <td>0.320000</td>
#       <td>0.680000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.829875</td>
#       <td>0.873649</td>
#       <td>0.326667</td>
#       <td>0.673333</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.6866666674613953.
# Better model found at epoch 1 with accuracy value: 0.699999988079071.

# %%
from AdaptTextLib.adapttext.evaluator.evaluator import Evaluator

evaluator = Evaluator()
evaluator.evaluate_ensemble(ensembleModel)
# Out:
# The accuracy is 0.699999988079071 %.
# The error rate is 0.30000001192092896 %.
# ROC area is 0.7035024154589371
#               precision    recall  f1-score   support
#
#            0       0.75      0.88      0.81        85
#            1       0.29      0.17      0.21        12
#            2       0.72      0.70      0.71        33
#            3       0.45      0.25      0.32        20
#
#     accuracy                           0.70       150
#    macro avg       0.55      0.50      0.51       150
# weighted avg       0.67      0.70      0.68       150
#
# --Mathews Correlation Coefficient--
# 0.4742657710133134
