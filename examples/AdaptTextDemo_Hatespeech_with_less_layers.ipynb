# %%
# !apt-get update
# !apt install -y git
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [395 kB]
# Get:6 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2116 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2181 kB]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1410 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [24.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [31.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2546 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [425 kB]
# Fetched 9381 kB in 1s (6919 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   git-man libasn1-8-heimdal libcurl3-gnutls liberror-perl libexpat1
#   libgdbm-compat4 libgdbm5 libgssapi3-heimdal libhcrypto4-heimdal
#   libheimbase1-heimdal libheimntlm0-heimdal libhx509-5-heimdal
#   libkrb5-26-heimdal libldap-2.4-2 libldap-common libnghttp2-14 libperl5.26
#   libpsl5 libroken18-heimdal librtmp1 libsasl2-2 libsasl2-modules
#   libsasl2-modules-db libsqlite3-0 libwind0-heimdal netbase patch perl
#   perl-modules-5.26 publicsuffix
# Suggested packages:
#   gettext-base git-daemon-run | git-daemon-sysvinit git-doc git-el git-email
#   git-gui gitk gitweb git-cvs git-mediawiki git-svn gdbm-l10n
#   libsasl2-modules-gssapi-mit | libsasl2-modules-gssapi-heimdal
#   libsasl2-modules-ldap libsasl2-modules-otp libsasl2-modules-sql ed
#   diffutils-doc perl-doc libterm-readline-gnu-perl
#   | libterm-readline-perl-perl make
# The following NEW packages will be installed:
#   git git-man libasn1-8-heimdal libcurl3-gnutls liberror-perl libexpat1
#   libgdbm-compat4 libgdbm5 libgssapi3-heimdal libhcrypto4-heimdal
#   libheimbase1-heimdal libheimntlm0-heimdal libhx509-5-heimdal
#   libkrb5-26-heimdal libldap-2.4-2 libldap-common libnghttp2-14 libperl5.26
#   libpsl5 libroken18-heimdal librtmp1 libsasl2-2 libsasl2-modules
#   libsasl2-modules-db libsqlite3-0 libwind0-heimdal netbase patch perl
#   perl-modules-5.26 publicsuffix
# 0 upgraded, 31 newly installed, 0 to remove and 10 not upgraded.
# Need to get 13.5 MB of archives.
# After this operation, 82.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 perl-modules-5.26 all 5.26.1-6ubuntu0.5 [2762 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdbm5 amd64 1.14.1-6 [26.0 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdbm-compat4 amd64 1.14.1-6 [6084 B]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libperl5.26 amd64 5.26.1-6ubuntu0.5 [3534 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 perl amd64 5.26.1-6ubuntu0.5 [201 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libexpat1 amd64 2.2.5-3ubuntu0.2 [80.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsqlite3-0 amd64 3.22.0-1ubuntu0.4 [499 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 netbase all 5.4 [12.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpsl5 amd64 0.19.1-5build1 [41.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 publicsuffix all 20180223.1310-1 [97.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libroken18-heimdal amd64 7.5.0+dfsg-1 [41.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libasn1-8-heimdal amd64 7.5.0+dfsg-1 [175 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libheimbase1-heimdal amd64 7.5.0+dfsg-1 [29.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhcrypto4-heimdal amd64 7.5.0+dfsg-1 [85.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwind0-heimdal amd64 7.5.0+dfsg-1 [47.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhx509-5-heimdal amd64 7.5.0+dfsg-1 [107 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libkrb5-26-heimdal amd64 7.5.0+dfsg-1 [206 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libheimntlm0-heimdal amd64 7.5.0+dfsg-1 [14.8 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgssapi3-heimdal amd64 7.5.0+dfsg-1 [96.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules-db amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [15.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-2 amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [49.2 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-common all 2.4.45+dfsg-1ubuntu1.10 [15.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-2.4-2 amd64 2.4.45+dfsg-1ubuntu1.10 [154 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnghttp2-14 amd64 1.30.0-1ubuntu1 [77.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 librtmp1 amd64 2.4+20151223.gitfa8646d.1-1 [54.2 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcurl3-gnutls amd64 7.58.0-2ubuntu3.13 [218 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 liberror-perl all 0.17025-1 [22.8 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 git-man all 1:2.17.1-1ubuntu0.8 [804 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 git amd64 1:2.17.1-1ubuntu0.8 [3916 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [48.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 patch amd64 2.7.6-2ubuntu1.1 [102 kB]
# Fetched 13.5 MB in 1s (22.0 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package perl-modules-5.26.
# (Reading database ... 6773 files and directories currently installed.)
# Preparing to unpack .../00-perl-modules-5.26_5.26.1-6ubuntu0.5_all.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking perl-modules-5.26 (5.26.1-6ubuntu0.5) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libgdbm5:amd64.
# Preparing to unpack .../01-libgdbm5_1.14.1-6_amd64.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking libgdbm5:amd64 (1.14.1-6) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libgdbm-compat4:amd64.
# Preparing to unpack .../02-libgdbm-compat4_1.14.1-6_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libgdbm-compat4:amd64 (1.14.1-6) ...
# 7Progress: [  5%] [##........................................................] 8Selecting previously unselected package libperl5.26:amd64.
# Preparing to unpack .../03-libperl5.26_5.26.1-6ubuntu0.5_amd64.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking libperl5.26:amd64 (5.26.1-6ubuntu0.5) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package perl.
# Preparing to unpack .../04-perl_5.26.1-6ubuntu0.5_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking perl (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package libexpat1:amd64.
# Preparing to unpack .../05-libexpat1_2.2.5-3ubuntu0.2_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libexpat1:amd64 (2.2.5-3ubuntu0.2) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libsqlite3-0:amd64.
# Preparing to unpack .../06-libsqlite3-0_3.22.0-1ubuntu0.4_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libsqlite3-0:amd64 (3.22.0-1ubuntu0.4) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package netbase.
# Preparing to unpack .../07-netbase_5.4_all.deb ...
# 7Progress: [ 14%] [########..................................................] 8Unpacking netbase (5.4) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libpsl5:amd64.
# Preparing to unpack .../08-libpsl5_0.19.1-5build1_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking libpsl5:amd64 (0.19.1-5build1) ...
# 7Progress: [ 17%] [##########................................................] 8Selecting previously unselected package publicsuffix.
# Preparing to unpack .../09-publicsuffix_20180223.1310-1_all.deb ...
# Unpacking publicsuffix (20180223.1310-1) ...
# 7Progress: [ 19%] [##########................................................] 87Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libroken18-heimdal:amd64.
# Preparing to unpack .../10-libroken18-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libroken18-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 21%] [###########...............................................] 87Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libasn1-8-heimdal:amd64.
# Preparing to unpack .../11-libasn1-8-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libasn1-8-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 22%] [#############.............................................] 87Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libheimbase1-heimdal:amd64.
# Preparing to unpack .../12-libheimbase1-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libheimbase1-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 24%] [##############............................................] 87Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libhcrypto4-heimdal:amd64.
# Preparing to unpack .../13-libhcrypto4-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libhcrypto4-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libwind0-heimdal:amd64.
# Preparing to unpack .../14-libwind0-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 28%] [###############...........................................] 8Unpacking libwind0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libhx509-5-heimdal:amd64.
# Preparing to unpack .../15-libhx509-5-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libhx509-5-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libkrb5-26-heimdal:amd64.
# Preparing to unpack .../16-libkrb5-26-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 31%] [##################........................................] 8Unpacking libkrb5-26-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libheimntlm0-heimdal:amd64.
# Preparing to unpack .../17-libheimntlm0-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking libheimntlm0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libgssapi3-heimdal:amd64.
# Preparing to unpack .../18-libgssapi3-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libgssapi3-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libsasl2-modules-db:amd64.
# Preparing to unpack .../19-libsasl2-modules-db_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package libsasl2-2:amd64.
# Preparing to unpack .../20-libsasl2-2_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package libldap-common.
# Preparing to unpack .../21-libldap-common_2.4.45+dfsg-1ubuntu1.10_all.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package libldap-2.4-2:amd64.
# Preparing to unpack .../22-libldap-2.4-2_2.4.45+dfsg-1ubuntu1.10_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 44%] [#########################.................................] 87Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libnghttp2-14:amd64.
# Preparing to unpack .../23-libnghttp2-14_1.30.0-1ubuntu1_amd64.deb ...
# Unpacking libnghttp2-14:amd64 (1.30.0-1ubuntu1) ...
# 7Progress: [ 46%] [##########################................................] 87Progress: [ 46%] [##########################................................] 8Selecting previously unselected package librtmp1:amd64.
# Preparing to unpack .../24-librtmp1_2.4+20151223.gitfa8646d.1-1_amd64.deb ...
# Unpacking librtmp1:amd64 (2.4+20151223.gitfa8646d.1-1) ...
# 7Progress: [ 47%] [###########################...............................] 87Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package libcurl3-gnutls:amd64.
# Preparing to unpack .../25-libcurl3-gnutls_7.58.0-2ubuntu3.13_amd64.deb ...
# Unpacking libcurl3-gnutls:amd64 (7.58.0-2ubuntu3.13) ...
# 7Progress: [ 49%] [############################..............................] 87Progress: [ 50%] [#############################.............................] 8Selecting previously unselected package liberror-perl.
# Preparing to unpack .../26-liberror-perl_0.17025-1_all.deb ...
# Unpacking liberror-perl (0.17025-1) ...
# 7Progress: [ 51%] [#############################.............................] 8Selecting previously unselected package git-man.
# Preparing to unpack .../27-git-man_1%3a2.17.1-1ubuntu0.8_all.deb ...
# 7Progress: [ 53%] [##############################............................] 8Unpacking git-man (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 53%] [##############################............................] 8Selecting previously unselected package git.
# Preparing to unpack .../28-git_1%3a2.17.1-1ubuntu0.8_amd64.deb ...
# 7Progress: [ 54%] [###############################...........................] 8Unpacking git (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 55%] [###############################...........................] 8Selecting previously unselected package libsasl2-modules:amd64.
# Preparing to unpack .../29-libsasl2-modules_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 56%] [################################..........................] 8Unpacking libsasl2-modules:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 57%] [#################################.........................] 8Selecting previously unselected package patch.
# Preparing to unpack .../30-patch_2.7.6-2ubuntu1.1_amd64.deb ...
# 7Progress: [ 58%] [#################################.........................] 8Unpacking patch (2.7.6-2ubuntu1.1) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up git-man (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libexpat1:amd64 (2.2.5-3ubuntu0.2) ...
# 7Progress: [ 62%] [###################################.......................] 87Progress: [ 62%] [####################################......................] 8Setting up libnghttp2-14:amd64 (1.30.0-1ubuntu1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libpsl5:amd64 (0.19.1-5build1) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 66%] [######################################....................] 8Setting up libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 67%] [#######################################...................] 8Setting up libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 69%] [#######################################...................] 8Setting up libroken18-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up librtmp1:amd64 (2.4+20151223.gitfa8646d.1-1) ...
# 7Progress: [ 71%] [########################################..................] 87Progress: [ 71%] [#########################################.................] 8Setting up perl-modules-5.26 (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 72%] [##########################################................] 8Setting up libgdbm5:amd64 (1.14.1-6) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up patch (2.7.6-2ubuntu1.1) ...
# 7Progress: [ 74%] [###########################################...............] 87Progress: [ 75%] [###########################################...............] 8Setting up publicsuffix (20180223.1310-1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libheimbase1-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 78%] [############################################..............] 8Setting up libsqlite3-0:amd64 (3.22.0-1ubuntu0.4) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libgdbm-compat4:amd64 (1.14.1-6) ...
# 7Progress: [ 79%] [##############################################............] 87Progress: [ 80%] [##############################################............] 8Setting up libsasl2-modules:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up netbase (5.4) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libwind0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libasn1-8-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 85%] [#################################################.........] 87Progress: [ 85%] [#################################################.........] 8Setting up libhcrypto4-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libhx509-5-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libperl5.26:amd64 (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 89%] [###################################################.......] 8Setting up libkrb5-26-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libheimntlm0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up perl (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libgssapi3-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 94%] [######################################################....] 87Progress: [ 94%] [######################################################....] 8Setting up liberror-perl (0.17025-1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libcurl3-gnutls:amd64 (7.58.0-2ubuntu3.13) ...
# 7Progress: [ 97%] [########################################################..] 87Progress: [ 98%] [########################################################..] 8Setting up git (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for libc-bin (2.27-3ubuntu1.4) ...
#
# 78

# %%
# !git clone https://gitlab.com/AdaptText/AdaptTextLib.git
# Out:
# Cloning into 'AdaptTextLib'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 780 (delta 85), reused 140 (delta 77), pack-reused 632
# Receiving objects: 100% (780/780), 1.43 MiB | 10.87 MiB/s, done.
# Resolving deltas: 100% (519/519), done.

# %%
# !cd AdaptTextLib && bash setup.sh
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:4 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 10 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Collecting wikiextractor==0.01
#   Downloading wikiextractor-0.1.tar.gz (36 kB)
# Collecting sentencepiece==0.1.95
#   Downloading sentencepiece-0.1.95-cp38-cp38-manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 12.8 MB/s eta 0:00:01
# Collecting ninja==1.10.0
#   Downloading ninja-1.10.0-py3-none-manylinux1_x86_64.whl (102 kB)
#      |████████████████████████████████| 102 kB 30.0 MB/s eta 0:00:01
# Collecting emoji==1.2.0
#   Downloading emoji-1.2.0-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 28.7 MB/s eta 0:00:01
# Collecting flask==1.1.2
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 5.3 MB/s  eta 0:00:01
# Collecting gunicorn==20.0.4
#   Downloading gunicorn-20.0.4-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 8.8 MB/s  eta 0:00:01
# Requirement already satisfied: torch in /opt/conda/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (1.8.1)
# Collecting python-dotenv==0.15.0
#   Downloading python_dotenv-0.15.0-py2.py3-none-any.whl (18 kB)
# Collecting dropbox==11.2.0
#   Downloading dropbox-11.2.0-py3-none-any.whl (555 kB)
#      |████████████████████████████████| 555 kB 27.4 MB/s eta 0:00:01
# Collecting dataclasses==0.6
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting spacy==2.3.5
#   Downloading spacy-2.3.5-cp38-cp38-manylinux2014_x86_64.whl (10.5 MB)
#      |████████████████████████████████| 10.5 MB 721 kB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (1.19.2)
# Collecting matplotlib
#   Downloading matplotlib-3.4.1-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 30.3 MB/s eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.1-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      |████████████████████████████████| 24.9 MB 42.3 MB/s eta 0:00:01
# Collecting fastprogress
#   Downloading fastprogress-1.0.0-py3-none-any.whl (12 kB)
# Collecting scipy==1.6.1
#   Downloading scipy-1.6.1-cp38-cp38-manylinux1_x86_64.whl (27.3 MB)
#      |████████████████████████████████| 27.3 MB 19.5 MB/s eta 0:00:01
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting pandas
#   Downloading pandas-1.2.4-cp38-cp38-manylinux1_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 22.2 MB/s eta 0:00:01
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 2.1 MB/s  eta 0:00:01
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/conda/lib/python3.8/site-packages (from flask==1.1.2->-r requirements.txt (line 5)) (2.11.3)
# Collecting Werkzeug>=0.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 35.9 MB/s eta 0:00:01
# Requirement already satisfied: setuptools>=3.0 in /opt/conda/lib/python3.8/site-packages (from gunicorn==20.0.4->-r requirements.txt (line 6)) (50.3.1.post20201107)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.8/site-packages (from torch->-r requirements.txt (line 8)) (3.7.4.3)
# Requirement already satisfied: requests>=2.16.2 in /opt/conda/lib/python3.8/site-packages (from dropbox==11.2.0->-r requirements.txt (line 10)) (2.24.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.8/site-packages (from dropbox==11.2.0->-r requirements.txt (line 10)) (1.15.0)
# Collecting stone>=2.*
#   Downloading stone-3.2.1-py3-none-any.whl (160 kB)
#      |████████████████████████████████| 160 kB 1.8 MB/s eta 0:00:01
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.5-cp38-cp38-manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 23.9 MB/s eta 0:00:01
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp38-cp38-manylinux2014_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 30.9 MB/s eta 0:00:01
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.5-cp38-cp38-manylinux2014_x86_64.whl (186 kB)
#      |████████████████████████████████| 186 kB 39.8 MB/s eta 0:00:01
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.8/site-packages (from spacy==2.3.5->-r requirements.txt (line 12)) (4.51.0)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp38-cp38-manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 21.0 MB/s eta 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp38-cp38-manylinux2014_x86_64.whl (20 kB)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp38-cp38-manylinux2014_x86_64.whl (35 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (2.8.1)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp38-cp38-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 18.9 MB/s eta 0:00:01
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (8.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (2.4.7)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 35.1 MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 20)) (2021.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from Jinja2>=2.10.1->flask==1.1.2->-r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (2.10)
# Collecting ply>=3.4
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 10.1 MB/s eta 0:00:01
# Building wheels for collected packages: wikiextractor, sklearn
#   Building wheel for wikiextractor (setup.py) ... done
#   Created wheel for wikiextractor: filename=wikiextractor-0.1-py3-none-any.whl size=38819 sha256=a9b2927bacf43e462330953865f539b239af486dcc14cab5462977caff37d59b
#   Stored in directory: /root/.cache/pip/wheels/98/50/4b/5a06f4f998b52f6b828af95aa4e1b3efb784b3210c970bcaf3
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=335ad1722a92fd19789df79302285de6aa8100f502e75bcc537b4362f7a375c2
#   Stored in directory: /root/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built wikiextractor sklearn
# Installing collected packages: wikiextractor, sentencepiece, ninja, emoji, click, itsdangerous, Werkzeug, flask, gunicorn, python-dotenv, ply, stone, dropbox, dataclasses, wasabi, plac, murmurhash, cymem, preshed, blis, catalogue, srsly, thinc, spacy, kiwisolver, cycler, matplotlib, scipy, joblib, threadpoolctl, scikit-learn, fastprogress, sklearn, pandas
# Successfully installed Werkzeug-1.0.1 blis-0.7.4 catalogue-1.0.0 click-7.1.2 cycler-0.10.0 cymem-2.0.5 dataclasses-0.6 dropbox-11.2.0 emoji-1.2.0 fastprogress-1.0.0 flask-1.1.2 gunicorn-20.0.4 itsdangerous-1.1.0 joblib-1.0.1 kiwisolver-1.3.1 matplotlib-3.4.1 murmurhash-1.0.5 ninja-1.10.0 pandas-1.2.4 plac-1.1.3 ply-3.11 preshed-3.0.5 python-dotenv-0.15.0 scikit-learn-0.24.1 scipy-1.6.1 sentencepiece-0.1.95 sklearn-0.0 spacy-2.3.5 srsly-1.0.5 stone-3.2.1 thinc-7.4.5 threadpoolctl-2.1.0 wasabi-0.8.2 wikiextractor-0.1
# Cloning into 'fastai1'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 155 (delta 29), reused 131 (delta 18), pack-reused 0
# Receiving objects: 100% (155/155), 207.89 KiB | 5.62 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# Cloning into 'Best-Deep-Learning-Optimizers'...
# remote: Enumerating objects: 211, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 211 (delta 14), reused 3 (delta 1), pack-reused 178
# Receiving objects: 100% (211/211), 858.72 KiB | 7.40 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
from AdaptTextLib.adapttext.adapt_text import AdaptText

lang = 'si'
app_root = "/storage"
bs = 128
splitting_ratio = 0.1
adapttext = AdaptText(lang, app_root, bs, splitting_ratio)

# %%
adapttext.prepare_pretrained_lm("full_si_dedup.zip")

# %%
import pandas as pd

pd.set_option('display.max_colwidth', -1)
# path_to_csv="sinhala-hate-speech-dataset.csv"
path_to_csv="sinhala-hate-speech-dataset.csv"
# path_to_csv="small_sin.csv"
df = pd.read_csv(path_to_csv)

text_name = "comment"
label_name = "label"

# print(df.head())

classifierModelFWD, classifierModelBWD, ensembleModel, classes = adapttext.build_classifier(df, text_name, label_name, grad_unfreeze=True)
# Out:
# 1    3455
# 0    2890
# Name: label, dtype: int64
# 1    3109
# 0    2601
# Name: label, dtype: int64
# 1    3109
# 0    2601
# Name: label, dtype: int64
# Training Forward model...
# [PosixPath('/storage/data/siwiki/models/si_wt'), PosixPath('/storage/data/siwiki/models/si_wt_vocab')]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       83.33% [5/6 00:05<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>7.022385</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.018223</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.009622</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.864490</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.502454</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='17' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       82.35% [14/17 00:00<00:00 13.1559]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 5.75E-02
# Min loss divided by 10: 4.37E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.276062</td>
#       <td>5.120052</td>
#       <td>0.753348</td>
#       <td>0.246652</td>
#       <td>167.344131</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.527412</td>
#       <td>4.997136</td>
#       <td>0.740402</td>
#       <td>0.259598</td>
#       <td>147.988663</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 5.120052337646484.
# Better model found at epoch 1 with valid_loss value: 4.997135639190674.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.609075</td>
#       <td>4.980225</td>
#       <td>0.753906</td>
#       <td>0.246094</td>
#       <td>145.506989</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.705369</td>
#       <td>5.209544</td>
#       <td>0.755134</td>
#       <td>0.244866</td>
#       <td>183.010620</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.839153</td>
#       <td>5.180647</td>
#       <td>0.747098</td>
#       <td>0.252902</td>
#       <td>177.797699</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.910777</td>
#       <td>5.780525</td>
#       <td>0.860603</td>
#       <td>0.139397</td>
#       <td>323.929291</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.782924</td>
#       <td>0.217076</td>
#       <td>nan</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.782924</td>
#       <td>0.217076</td>
#       <td>nan</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.782924</td>
#       <td>0.217076</td>
#       <td>nan</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.782924</td>
#       <td>0.217076</td>
#       <td>nan</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 4.980224609375.
# Epoch 1: reducing lr to 0.043626777749550275
# Epoch 2: reducing lr to 0.04455990930852094
# Epoch 3: reducing lr to 0.03702985905745631
# Epoch 4: reducing lr to 0.025273799622968298
# Epoch 5: reducing lr to 0.012837307238186227
# Epoch 6: reducing lr to 0.003471173745283011
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='95' class='' max='178' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       53.37% [95/178 00:02<00:02 0.9611]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-07
# Min loss divided by 10: 1.10E-01
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.887381</td>
#       <td>0.871002</td>
#       <td>0.393701</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.879882</td>
#       <td>0.842123</td>
#       <td>0.409449</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.861815</td>
#       <td>0.840804</td>
#       <td>0.425197</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.850078</td>
#       <td>0.814059</td>
#       <td>0.439370</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.846489</td>
#       <td>0.821190</td>
#       <td>0.442520</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.821782</td>
#       <td>0.781050</td>
#       <td>0.478740</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.796729</td>
#       <td>0.760011</td>
#       <td>0.503937</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.788352</td>
#       <td>0.760887</td>
#       <td>0.507087</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.786749</td>
#       <td>0.769933</td>
#       <td>0.499213</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.781934</td>
#       <td>0.747742</td>
#       <td>0.521260</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.778900</td>
#       <td>0.758728</td>
#       <td>0.496063</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.782764</td>
#       <td>0.744883</td>
#       <td>0.513386</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.8710019588470459.
# Better model found at epoch 1 with valid_loss value: 0.8421230316162109.
# Better model found at epoch 2 with valid_loss value: 0.840803861618042.
# Better model found at epoch 3 with valid_loss value: 0.8140590190887451.
# Better model found at epoch 5 with valid_loss value: 0.7810496687889099.
# Better model found at epoch 6 with valid_loss value: 0.760010838508606.
# Better model found at epoch 9 with valid_loss value: 0.7477419376373291.
# Better model found at epoch 11 with valid_loss value: 0.7448826432228088.
# The accuracy is 0.5133858323097229 %.
# Gradual Unfreezing..
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.780270</td>
#       <td>0.735459</td>
#       <td>0.529134</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.774399</td>
#       <td>0.719319</td>
#       <td>0.541732</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.758648</td>
#       <td>0.734429</td>
#       <td>0.540157</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.756391</td>
#       <td>0.734654</td>
#       <td>0.530709</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.726095</td>
#       <td>0.694555</td>
#       <td>0.576378</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.721483</td>
#       <td>0.694907</td>
#       <td>0.579528</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.715482</td>
#       <td>0.696204</td>
#       <td>0.574803</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.722256</td>
#       <td>0.701388</td>
#       <td>0.559055</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.7354586124420166.
# Better model found at epoch 1 with valid_loss value: 0.7193189859390259.
# Better model found at epoch 4 with valid_loss value: 0.6945547461509705.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.727696</td>
#       <td>0.701645</td>
#       <td>0.557480</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.710642</td>
#       <td>0.683037</td>
#       <td>0.593701</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.688909</td>
#       <td>0.665975</td>
#       <td>0.598425</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.686408</td>
#       <td>0.666143</td>
#       <td>0.603150</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.673903</td>
#       <td>0.649984</td>
#       <td>0.620472</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.675171</td>
#       <td>0.656480</td>
#       <td>0.615748</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.7016452550888062.
# Better model found at epoch 1 with valid_loss value: 0.6830369830131531.
# Better model found at epoch 2 with valid_loss value: 0.6659747958183289.
# Better model found at epoch 4 with valid_loss value: 0.649983823299408.
# Completely Unfreezing..
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='96' class='' max='178' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       53.93% [96/178 00:05<00:04 1.7950]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.74E-03
# Min loss divided by 10: 1.74E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.385237</td>
#       <td>0.336996</td>
#       <td>0.862992</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.293376</td>
#       <td>0.321489</td>
#       <td>0.861417</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.155797</td>
#       <td>0.392266</td>
#       <td>0.869291</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.072731</td>
#       <td>0.447217</td>
#       <td>0.874016</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.045354</td>
#       <td>0.474436</td>
#       <td>0.867717</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.033680</td>
#       <td>0.476156</td>
#       <td>0.867717</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.3369958698749542.
# Better model found at epoch 1 with valid_loss value: 0.3214891850948334.
# Epoch 2: reducing lr to 0.001127869348027571
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.141069</td>
#       <td>0.348773</td>
#       <td>0.859843</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.104580</td>
#       <td>0.384968</td>
#       <td>0.862992</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.075837</td>
#       <td>0.466348</td>
#       <td>0.861417</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.050819</td>
#       <td>0.489685</td>
#       <td>0.864567</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.033631</td>
#       <td>0.508378</td>
#       <td>0.861417</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.036124</td>
#       <td>0.543955</td>
#       <td>0.870866</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.34877270460128784.
# The accuracy is 0.8598425388336182 %.
# Training Backward model...
# [PosixPath('/storage/data/siwiki/models/si_wt_bwd'), PosixPath('/storage/data/siwiki/models/si_wt_vocab_bwd')]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       83.33% [5/6 00:05<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.939641</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.936887</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.928832</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.765415</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.440702</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='17' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       82.35% [14/17 00:00<00:00 12.7248]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 5.75E-02
# Min loss divided by 10: 6.31E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.247218</td>
#       <td>5.099691</td>
#       <td>0.761384</td>
#       <td>0.238616</td>
#       <td>163.971298</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.540877</td>
#       <td>4.997385</td>
#       <td>0.753795</td>
#       <td>0.246205</td>
#       <td>148.025574</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 5.099691390991211.
# Better model found at epoch 1 with valid_loss value: 4.997385025024414.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.663904</td>
#       <td>5.075476</td>
#       <td>0.777567</td>
#       <td>0.222433</td>
#       <td>160.048233</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.722659</td>
#       <td>5.173846</td>
#       <td>0.771763</td>
#       <td>0.228237</td>
#       <td>176.592758</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.828746</td>
#       <td>5.216670</td>
#       <td>0.772545</td>
#       <td>0.227455</td>
#       <td>184.319305</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.400330</td>
#       <td>8.231515</td>
#       <td>0.836719</td>
#       <td>0.163281</td>
#       <td>3757.521973</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.783705</td>
#       <td>0.216295</td>
#       <td>nan</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.783705</td>
#       <td>0.216295</td>
#       <td>nan</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.783705</td>
#       <td>0.216295</td>
#       <td>nan</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.783705</td>
#       <td>0.216295</td>
#       <td>nan</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 5.075475692749023.
# Epoch 1: reducing lr to 0.043626777749550275
# Epoch 2: reducing lr to 0.04455990930852094
# Epoch 3: reducing lr to 0.03702985905745631
# Epoch 4: reducing lr to 0.025273799622968298
# Epoch 5: reducing lr to 0.012837307238186227
# Epoch 6: reducing lr to 0.003471173745283011
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='93' class='' max='178' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.25% [93/178 00:02<00:02 0.6970]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.32E-02
# Min loss divided by 10: 3.63E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.425401</td>
#       <td>0.362408</td>
#       <td>0.833071</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.414493</td>
#       <td>0.374209</td>
#       <td>0.831496</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.434210</td>
#       <td>0.376750</td>
#       <td>0.850394</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.412459</td>
#       <td>0.420119</td>
#       <td>0.796850</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.387079</td>
#       <td>0.365696</td>
#       <td>0.847244</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.388046</td>
#       <td>0.372857</td>
#       <td>0.847244</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.360525</td>
#       <td>0.369430</td>
#       <td>0.855118</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.344269</td>
#       <td>0.366840</td>
#       <td>0.837795</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.374110</td>
#       <td>0.376586</td>
#       <td>0.828346</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.340576</td>
#       <td>0.358321</td>
#       <td>0.842520</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.328704</td>
#       <td>0.360994</td>
#       <td>0.839370</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.302622</td>
#       <td>0.362500</td>
#       <td>0.837795</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.36240771412849426.
# Epoch 1: reducing lr to 0.006373847414039244
# Epoch 2: reducing lr to 0.009876119680203872
# Epoch 3: reducing lr to 0.01048589467791998
# Epoch 4: reducing lr to 0.009835909507761165
# Epoch 5: reducing lr to 0.008555763949765012
# Epoch 6: reducing lr to 0.006822254303388455
# Epoch 7: reducing lr to 0.004874789351982685
# Epoch 8: reducing lr to 0.0029823264766673727
# Better model found at epoch 9 with valid_loss value: 0.3583212196826935.
# The accuracy is 0.8425197005271912 %.
# Gradual Unfreezing..
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.375987</td>
#       <td>0.412541</td>
#       <td>0.826772</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.383725</td>
#       <td>0.395146</td>
#       <td>0.845669</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.340369</td>
#       <td>0.425231</td>
#       <td>0.833071</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.276956</td>
#       <td>0.421320</td>
#       <td>0.829921</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.246232</td>
#       <td>0.472806</td>
#       <td>0.839370</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.181635</td>
#       <td>0.495432</td>
#       <td>0.847244</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.126545</td>
#       <td>0.523062</td>
#       <td>0.848819</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.126204</td>
#       <td>0.483901</td>
#       <td>0.847244</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.4125412404537201.
# Better model found at epoch 1 with valid_loss value: 0.39514589309692383.
# Epoch 2: reducing lr to 0.010249169637676997
# Epoch 3: reducing lr to 0.008558857306663696
# Epoch 4: reducing lr to 0.005861668314962786
# Epoch 5: reducing lr to 0.0029841073163879954
# Epoch 6: reducing lr to 0.0008079506952686694
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.340868</td>
#       <td>0.441353</td>
#       <td>0.792126</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.315751</td>
#       <td>0.343950</td>
#       <td>0.862992</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.278938</td>
#       <td>0.450407</td>
#       <td>0.845669</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.172648</td>
#       <td>0.517509</td>
#       <td>0.859843</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.101893</td>
#       <td>0.614931</td>
#       <td>0.861417</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.052660</td>
#       <td>0.617116</td>
#       <td>0.859843</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.44135338068008423.
# Better model found at epoch 1 with valid_loss value: 0.3439500331878662.
# Epoch 2: reducing lr to 0.008555763949765012
# Epoch 3: reducing lr to 0.004874789351982685
# Epoch 4: reducing lr to 0.0014062269196274428
# Completely Unfreezing..
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='93' class='' max='178' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.25% [93/178 00:04<00:04 0.6140]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 9.12E-07
# Min loss divided by 10: 2.29E-05
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.258822</td>
#       <td>0.343469</td>
#       <td>0.847244</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.261345</td>
#       <td>0.356515</td>
#       <td>0.837795</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.252539</td>
#       <td>0.341469</td>
#       <td>0.848819</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.243256</td>
#       <td>0.349918</td>
#       <td>0.844095</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.248191</td>
#       <td>0.341347</td>
#       <td>0.848819</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.240870</td>
#       <td>0.342493</td>
#       <td>0.853543</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.34346944093704224.
# Better model found at epoch 2 with valid_loss value: 0.3414689600467682.
# Better model found at epoch 4 with valid_loss value: 0.34134718775749207.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.255749</td>
#       <td>0.357852</td>
#       <td>0.833071</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.249683</td>
#       <td>0.343041</td>
#       <td>0.848819</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.262506</td>
#       <td>0.351113</td>
#       <td>0.844095</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.250553</td>
#       <td>0.344282</td>
#       <td>0.850394</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.250272</td>
#       <td>0.342426</td>
#       <td>0.850394</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.255336</td>
#       <td>0.341702</td>
#       <td>0.848819</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.35785216093063354.
# Better model found at epoch 1 with valid_loss value: 0.343041330575943.
# Better model found at epoch 4 with valid_loss value: 0.34242621064186096.
# Better model found at epoch 5 with valid_loss value: 0.3417016863822937.
# The accuracy is 0.8488188982009888 %.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       84.62% [11/13 00:10<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.513484</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.507152</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.511731</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.510122</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.494273</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.463748</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.431248</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.415826</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.393199</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.388602</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.392472</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='8' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       87.50% [7/8 00:00<00:00 0.7738]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.45E-03
# Min loss divided by 10: 3.63E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.464462</td>
#       <td>0.603100</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.387539</td>
#       <td>0.427439</td>
#       <td>0.158730</td>
#       <td>0.841270</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.364269</td>
#       <td>0.379388</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.346325</td>
#       <td>0.366165</td>
#       <td>0.158730</td>
#       <td>0.841270</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.333206</td>
#       <td>0.359658</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.325447</td>
#       <td>0.360048</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.319518</td>
#       <td>0.357419</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.313694</td>
#       <td>0.361063</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.6030997633934021.
# Better model found at epoch 1 with valid_loss value: 0.4274389445781708.
# Better model found at epoch 2 with valid_loss value: 0.37938767671585083.
# Better model found at epoch 3 with valid_loss value: 0.366164892911911.
# Better model found at epoch 4 with valid_loss value: 0.35965776443481445.
# Better model found at epoch 6 with valid_loss value: 0.3574187457561493.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.299033</td>
#       <td>0.358966</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.294841</td>
#       <td>0.355815</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.290690</td>
#       <td>0.356922</td>
#       <td>0.158730</td>
#       <td>0.841270</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.294688</td>
#       <td>0.362414</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.291253</td>
#       <td>0.366468</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.286541</td>
#       <td>0.371729</td>
#       <td>0.206349</td>
#       <td>0.793651</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.286529</td>
#       <td>0.374092</td>
#       <td>0.206349</td>
#       <td>0.793651</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.283994</td>
#       <td>0.377548</td>
#       <td>0.206349</td>
#       <td>0.793651</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.35896557569503784.
# Better model found at epoch 1 with valid_loss value: 0.3558148443698883.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.289294</td>
#       <td>0.356208</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.290574</td>
#       <td>0.360816</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.293139</td>
#       <td>0.365255</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.295888</td>
#       <td>0.366845</td>
#       <td>0.174603</td>
#       <td>0.825397</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.291538</td>
#       <td>0.369065</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.291211</td>
#       <td>0.371716</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.292398</td>
#       <td>0.376051</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.288171</td>
#       <td>0.380970</td>
#       <td>0.190476</td>
#       <td>0.809524</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.8253968954086304.

# %%
from AdaptTextLib.adapttext.evaluator.evaluator import Evaluator

evaluator = Evaluator()
evaluator.evaluate(ensembleModel, classifierModelFWD)
# Out:
# The accuracy is 0.8253968358039856 %.
# The error rate is 0.1746031641960144 %.
# ROC area is 0.922920892494929
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83        34
#            1       0.78      0.86      0.82        29
#
#     accuracy                           0.83        63
#    macro avg       0.83      0.83      0.83        63
# weighted avg       0.83      0.83      0.83        63
#
# --Mathews Correlation Coefficient--
# 0.6541991674885067
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Text</th>
#       <th>Prediction</th>
#       <th>Actual</th>
#       <th>Loss</th>
#       <th>Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos ගෑනිගෙ මිනිහ කොහොම ඉන්නව ඇත්ද අප්පා ගෑනිගෙ කට නිසා ... xxunk ගෑනු xxrep 4 . අපහාස වලට xxunk පුලුවන් xxunk නෙමෙයි අජිත් රෝහන xxunk ...</td>
#       <td>1</td>
#       <td>0</td>
#       <td>4.07</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <td>xxbos අනෙ නිකන් පලයං xxrep 5 .</td>
#       <td>1</td>
#       <td>0</td>
#       <td>4.07</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <td>xxbos උත්තර xxunk xxunk ඇත්ත xxunk නිසි පිලිතුරු නිසි xxunk ලැබෙන විශ්වාසයි .. තෙරුවන් සරණයි</td>
#       <td>0</td>
#       <td>1</td>
#       <td>4.03</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <td>xxbos xxunk මේකෙ xxunk හදනව ...</td>
#       <td>0</td>
#       <td>1</td>
#       <td>3.97</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <td>xxbos නෑ ඒකි කතා දන්නෑ xxunk තියෙන කතා කොච්චර වැරදි xxunk කතා ක්‍රමයක් තියෙනවා xxunk xxunk ගිහිල්ලා xxunk කරල ළමයි හදා ගත්තට මිනිස්සු xxunk xxunk මිනිස්සු ලංකාවට අපහාස නැති xxunk සිය බුදු සරණයි ඔයාට පරිස්සමට ඉන්න xxunk</td>
#       <td>1</td>
#       <td>0</td>
#       <td>3.84</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <td>xxbos එක දෙයක් මෙයාට xxunk මෙයා යම් කිසි xxunk ජීවත් මෙයා xxunk දේවල් බලාගන්නම් කියන්න අඩු ගානේ xxunk කෙනෙක් කෙනෙක් මෙයා කවුද මෙයා බත් කඩේ අත් දාගෙන ජීවත් විදේශ xxunk මතක තියා ගන්න වෛරසය xxunk බැරි xxunk ඊ ක්‍රියා xxunk විදේශ xxunk රටවල් වලට පිටුවහල් xxunk හිතනවා xxunk හිතන්න</td>
#       <td>1</td>
#       <td>0</td>
#       <td>3.83</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <td>xxbos xxunk තොත් xxunk</td>
#       <td>1</td>
#       <td>0</td>
#       <td>3.70</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <td>xxbos ඕක කියන්නෙ xxrep 4 ?</td>
#       <td>0</td>
#       <td>1</td>
#       <td>3.66</td>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <td>xxbos දොස්තර අබ්දුල් රාසික්</td>
#       <td>1</td>
#       <td>0</td>
#       <td>3.61</td>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <td>xxbos xxunk පනින්න එපා ... xxunk xxunk ගනිල්ලා</td>
#       <td>1</td>
#       <td>0</td>
#       <td>3.52</td>
#       <td>0.03</td>
#     </tr>
#   </tbody>
# </table>
