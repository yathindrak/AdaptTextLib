# %%
# !apt-get update
# !apt install -y git
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [31.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2181 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2546 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [425 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [395 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [24.5 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2116 kB]
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1410 kB]
# Fetched 9381 kB in 1s (6307 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   git-man libasn1-8-heimdal libcurl3-gnutls liberror-perl libexpat1
#   libgdbm-compat4 libgdbm5 libgssapi3-heimdal libhcrypto4-heimdal
#   libheimbase1-heimdal libheimntlm0-heimdal libhx509-5-heimdal
#   libkrb5-26-heimdal libldap-2.4-2 libldap-common libnghttp2-14 libperl5.26
#   libpsl5 libroken18-heimdal librtmp1 libsasl2-2 libsasl2-modules
#   libsasl2-modules-db libsqlite3-0 libwind0-heimdal netbase patch perl
#   perl-modules-5.26 publicsuffix
# Suggested packages:
#   gettext-base git-daemon-run | git-daemon-sysvinit git-doc git-el git-email
#   git-gui gitk gitweb git-cvs git-mediawiki git-svn gdbm-l10n
#   libsasl2-modules-gssapi-mit | libsasl2-modules-gssapi-heimdal
#   libsasl2-modules-ldap libsasl2-modules-otp libsasl2-modules-sql ed
#   diffutils-doc perl-doc libterm-readline-gnu-perl
#   | libterm-readline-perl-perl make
# The following NEW packages will be installed:
#   git git-man libasn1-8-heimdal libcurl3-gnutls liberror-perl libexpat1
#   libgdbm-compat4 libgdbm5 libgssapi3-heimdal libhcrypto4-heimdal
#   libheimbase1-heimdal libheimntlm0-heimdal libhx509-5-heimdal
#   libkrb5-26-heimdal libldap-2.4-2 libldap-common libnghttp2-14 libperl5.26
#   libpsl5 libroken18-heimdal librtmp1 libsasl2-2 libsasl2-modules
#   libsasl2-modules-db libsqlite3-0 libwind0-heimdal netbase patch perl
#   perl-modules-5.26 publicsuffix
# 0 upgraded, 31 newly installed, 0 to remove and 10 not upgraded.
# Need to get 13.5 MB of archives.
# After this operation, 82.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 perl-modules-5.26 all 5.26.1-6ubuntu0.5 [2762 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdbm5 amd64 1.14.1-6 [26.0 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdbm-compat4 amd64 1.14.1-6 [6084 B]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libperl5.26 amd64 5.26.1-6ubuntu0.5 [3534 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 perl amd64 5.26.1-6ubuntu0.5 [201 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libexpat1 amd64 2.2.5-3ubuntu0.2 [80.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsqlite3-0 amd64 3.22.0-1ubuntu0.4 [499 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 netbase all 5.4 [12.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpsl5 amd64 0.19.1-5build1 [41.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 publicsuffix all 20180223.1310-1 [97.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libroken18-heimdal amd64 7.5.0+dfsg-1 [41.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libasn1-8-heimdal amd64 7.5.0+dfsg-1 [175 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libheimbase1-heimdal amd64 7.5.0+dfsg-1 [29.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhcrypto4-heimdal amd64 7.5.0+dfsg-1 [85.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwind0-heimdal amd64 7.5.0+dfsg-1 [47.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhx509-5-heimdal amd64 7.5.0+dfsg-1 [107 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libkrb5-26-heimdal amd64 7.5.0+dfsg-1 [206 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libheimntlm0-heimdal amd64 7.5.0+dfsg-1 [14.8 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgssapi3-heimdal amd64 7.5.0+dfsg-1 [96.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules-db amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [15.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-2 amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [49.2 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-common all 2.4.45+dfsg-1ubuntu1.10 [15.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-2.4-2 amd64 2.4.45+dfsg-1ubuntu1.10 [154 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnghttp2-14 amd64 1.30.0-1ubuntu1 [77.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 librtmp1 amd64 2.4+20151223.gitfa8646d.1-1 [54.2 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcurl3-gnutls amd64 7.58.0-2ubuntu3.13 [218 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 liberror-perl all 0.17025-1 [22.8 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 git-man all 1:2.17.1-1ubuntu0.8 [804 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 git amd64 1:2.17.1-1ubuntu0.8 [3916 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [48.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 patch amd64 2.7.6-2ubuntu1.1 [102 kB]
# Fetched 13.5 MB in 1s (21.9 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package perl-modules-5.26.
# (Reading database ... 6773 files and directories currently installed.)
# Preparing to unpack .../00-perl-modules-5.26_5.26.1-6ubuntu0.5_all.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking perl-modules-5.26 (5.26.1-6ubuntu0.5) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libgdbm5:amd64.
# Preparing to unpack .../01-libgdbm5_1.14.1-6_amd64.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking libgdbm5:amd64 (1.14.1-6) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libgdbm-compat4:amd64.
# Preparing to unpack .../02-libgdbm-compat4_1.14.1-6_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libgdbm-compat4:amd64 (1.14.1-6) ...
# 7Progress: [  5%] [##........................................................] 8Selecting previously unselected package libperl5.26:amd64.
# Preparing to unpack .../03-libperl5.26_5.26.1-6ubuntu0.5_amd64.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking libperl5.26:amd64 (5.26.1-6ubuntu0.5) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package perl.
# Preparing to unpack .../04-perl_5.26.1-6ubuntu0.5_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking perl (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package libexpat1:amd64.
# Preparing to unpack .../05-libexpat1_2.2.5-3ubuntu0.2_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libexpat1:amd64 (2.2.5-3ubuntu0.2) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libsqlite3-0:amd64.
# Preparing to unpack .../06-libsqlite3-0_3.22.0-1ubuntu0.4_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libsqlite3-0:amd64 (3.22.0-1ubuntu0.4) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package netbase.
# Preparing to unpack .../07-netbase_5.4_all.deb ...
# 7Progress: [ 14%] [########..................................................] 8Unpacking netbase (5.4) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libpsl5:amd64.
# Preparing to unpack .../08-libpsl5_0.19.1-5build1_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking libpsl5:amd64 (0.19.1-5build1) ...
# 7Progress: [ 17%] [##########................................................] 8Selecting previously unselected package publicsuffix.
# Preparing to unpack .../09-publicsuffix_20180223.1310-1_all.deb ...
# Unpacking publicsuffix (20180223.1310-1) ...
# 7Progress: [ 19%] [##########................................................] 87Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libroken18-heimdal:amd64.
# Preparing to unpack .../10-libroken18-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libroken18-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 21%] [###########...............................................] 87Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libasn1-8-heimdal:amd64.
# Preparing to unpack .../11-libasn1-8-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libasn1-8-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 22%] [#############.............................................] 87Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libheimbase1-heimdal:amd64.
# Preparing to unpack .../12-libheimbase1-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libheimbase1-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 24%] [##############............................................] 87Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libhcrypto4-heimdal:amd64.
# Preparing to unpack .../13-libhcrypto4-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libhcrypto4-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libwind0-heimdal:amd64.
# Preparing to unpack .../14-libwind0-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 28%] [###############...........................................] 8Unpacking libwind0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libhx509-5-heimdal:amd64.
# Preparing to unpack .../15-libhx509-5-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libhx509-5-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libkrb5-26-heimdal:amd64.
# Preparing to unpack .../16-libkrb5-26-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 31%] [##################........................................] 8Unpacking libkrb5-26-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libheimntlm0-heimdal:amd64.
# Preparing to unpack .../17-libheimntlm0-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking libheimntlm0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libgssapi3-heimdal:amd64.
# Preparing to unpack .../18-libgssapi3-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libgssapi3-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libsasl2-modules-db:amd64.
# Preparing to unpack .../19-libsasl2-modules-db_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package libsasl2-2:amd64.
# Preparing to unpack .../20-libsasl2-2_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package libldap-common.
# Preparing to unpack .../21-libldap-common_2.4.45+dfsg-1ubuntu1.10_all.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package libldap-2.4-2:amd64.
# Preparing to unpack .../22-libldap-2.4-2_2.4.45+dfsg-1ubuntu1.10_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 44%] [#########################.................................] 87Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libnghttp2-14:amd64.
# Preparing to unpack .../23-libnghttp2-14_1.30.0-1ubuntu1_amd64.deb ...
# Unpacking libnghttp2-14:amd64 (1.30.0-1ubuntu1) ...
# 7Progress: [ 46%] [##########################................................] 87Progress: [ 46%] [##########################................................] 8Selecting previously unselected package librtmp1:amd64.
# Preparing to unpack .../24-librtmp1_2.4+20151223.gitfa8646d.1-1_amd64.deb ...
# Unpacking librtmp1:amd64 (2.4+20151223.gitfa8646d.1-1) ...
# 7Progress: [ 47%] [###########################...............................] 87Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package libcurl3-gnutls:amd64.
# Preparing to unpack .../25-libcurl3-gnutls_7.58.0-2ubuntu3.13_amd64.deb ...
# Unpacking libcurl3-gnutls:amd64 (7.58.0-2ubuntu3.13) ...
# 7Progress: [ 49%] [############################..............................] 87Progress: [ 50%] [#############################.............................] 8Selecting previously unselected package liberror-perl.
# Preparing to unpack .../26-liberror-perl_0.17025-1_all.deb ...
# Unpacking liberror-perl (0.17025-1) ...
# 7Progress: [ 51%] [#############################.............................] 8Selecting previously unselected package git-man.
# Preparing to unpack .../27-git-man_1%3a2.17.1-1ubuntu0.8_all.deb ...
# 7Progress: [ 53%] [##############################............................] 8Unpacking git-man (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 53%] [##############################............................] 8Selecting previously unselected package git.
# Preparing to unpack .../28-git_1%3a2.17.1-1ubuntu0.8_amd64.deb ...
# 7Progress: [ 54%] [###############################...........................] 8Unpacking git (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 55%] [###############################...........................] 8Selecting previously unselected package libsasl2-modules:amd64.
# Preparing to unpack .../29-libsasl2-modules_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 56%] [################################..........................] 8Unpacking libsasl2-modules:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 57%] [#################################.........................] 8Selecting previously unselected package patch.
# Preparing to unpack .../30-patch_2.7.6-2ubuntu1.1_amd64.deb ...
# 7Progress: [ 58%] [#################################.........................] 8Unpacking patch (2.7.6-2ubuntu1.1) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up git-man (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libexpat1:amd64 (2.2.5-3ubuntu0.2) ...
# 7Progress: [ 62%] [###################################.......................] 87Progress: [ 62%] [####################################......................] 8Setting up libnghttp2-14:amd64 (1.30.0-1ubuntu1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libpsl5:amd64 (0.19.1-5build1) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 66%] [######################################....................] 8Setting up libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 67%] [#######################################...................] 8Setting up libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 69%] [#######################################...................] 8Setting up libroken18-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up librtmp1:amd64 (2.4+20151223.gitfa8646d.1-1) ...
# 7Progress: [ 71%] [########################################..................] 87Progress: [ 71%] [#########################################.................] 8Setting up perl-modules-5.26 (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 72%] [##########################################................] 8Setting up libgdbm5:amd64 (1.14.1-6) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up patch (2.7.6-2ubuntu1.1) ...
# 7Progress: [ 74%] [###########################################...............] 87Progress: [ 75%] [###########################################...............] 8Setting up publicsuffix (20180223.1310-1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libheimbase1-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 78%] [############################################..............] 8Setting up libsqlite3-0:amd64 (3.22.0-1ubuntu0.4) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libgdbm-compat4:amd64 (1.14.1-6) ...
# 7Progress: [ 79%] [##############################################............] 87Progress: [ 80%] [##############################################............] 8Setting up libsasl2-modules:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up netbase (5.4) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libwind0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libasn1-8-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 85%] [#################################################.........] 87Progress: [ 85%] [#################################################.........] 8Setting up libhcrypto4-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libhx509-5-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libperl5.26:amd64 (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 89%] [###################################################.......] 8Setting up libkrb5-26-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libheimntlm0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up perl (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libgssapi3-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 94%] [######################################################....] 87Progress: [ 94%] [######################################################....] 8Setting up liberror-perl (0.17025-1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libcurl3-gnutls:amd64 (7.58.0-2ubuntu3.13) ...
# 7Progress: [ 97%] [########################################################..] 87Progress: [ 98%] [########################################################..] 8Setting up git (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for libc-bin (2.27-3ubuntu1.4) ...
#
# 78

# %%
# !git clone https://gitlab.com/AdaptText/AdaptTextLib.git
# Out:
# Cloning into 'AdaptTextLib'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 780 (delta 85), reused 140 (delta 77), pack-reused 632
# Receiving objects: 100% (780/780), 1.43 MiB | 6.79 MiB/s, done.
# Resolving deltas: 100% (519/519), done.

# %%
# !cd AdaptTextLib && bash setup.sh
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic-updates InRelease                m
# Hit:3 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:4 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 10 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Collecting wikiextractor==0.01
#   Downloading wikiextractor-0.1.tar.gz (36 kB)
# Collecting sentencepiece==0.1.95
#   Downloading sentencepiece-0.1.95-cp38-cp38-manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 26.3 MB/s eta 0:00:01
# Collecting ninja==1.10.0
#   Downloading ninja-1.10.0-py3-none-manylinux1_x86_64.whl (102 kB)
#      |████████████████████████████████| 102 kB 134.8 MB/s eta 0:00:01
# Collecting emoji==1.2.0
#   Downloading emoji-1.2.0-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 118.1 MB/s eta 0:00:01
# Collecting flask==1.1.2
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 6.1 MB/s s eta 0:00:01
# Collecting gunicorn==20.0.4
#   Downloading gunicorn-20.0.4-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 5.7 MB/s  eta 0:00:01
# Requirement already satisfied: torch in /opt/conda/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (1.8.1)
# Collecting python-dotenv==0.15.0
#   Downloading python_dotenv-0.15.0-py2.py3-none-any.whl (18 kB)
# Collecting dropbox==11.2.0
#   Downloading dropbox-11.2.0-py3-none-any.whl (555 kB)
#      |████████████████████████████████| 555 kB 43.1 MB/s eta 0:00:01
# Collecting dataclasses==0.6
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting spacy==2.3.5
#   Downloading spacy-2.3.5-cp38-cp38-manylinux2014_x86_64.whl (10.5 MB)
#      |████████████████████████████████| 10.5 MB 33.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (1.19.2)
# Collecting matplotlib
#   Downloading matplotlib-3.4.1-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 1.9 MB/s eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.1-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      |████████████████████████████████| 24.9 MB 26.4 MB/s eta 0:00:01
# Collecting fastprogress
#   Downloading fastprogress-1.0.0-py3-none-any.whl (12 kB)
# Collecting scipy==1.6.1
#   Downloading scipy-1.6.1-cp38-cp38-manylinux1_x86_64.whl (27.3 MB)
#      |████████████████████████████████| 27.3 MB 33.4 MB/s eta 0:00:01
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting pandas
#   Downloading pandas-1.2.4-cp38-cp38-manylinux1_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 28.8 MB/s eta 0:00:01
# Collecting Werkzeug>=0.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 106.4 MB/s eta 0:00:01
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/conda/lib/python3.8/site-packages (from flask==1.1.2->-r requirements.txt (line 5)) (2.11.3)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 761 kB/s s eta 0:00:01
# Requirement already satisfied: setuptools>=3.0 in /opt/conda/lib/python3.8/site-packages (from gunicorn==20.0.4->-r requirements.txt (line 6)) (50.3.1.post20201107)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.8/site-packages (from torch->-r requirements.txt (line 8)) (3.7.4.3)
# Requirement already satisfied: requests>=2.16.2 in /opt/conda/lib/python3.8/site-packages (from dropbox==11.2.0->-r requirements.txt (line 10)) (2.24.0)
# Collecting stone>=2.*
#   Downloading stone-3.2.1-py3-none-any.whl (160 kB)
#      |████████████████████████████████| 160 kB 78.5 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.8/site-packages (from dropbox==11.2.0->-r requirements.txt (line 10)) (1.15.0)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.5-cp38-cp38-manylinux2014_x86_64.whl (186 kB)
#      |████████████████████████████████| 186 kB 81.5 MB/s eta 0:00:01
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.8/site-packages (from spacy==2.3.5->-r requirements.txt (line 12)) (4.51.0)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp38-cp38-manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 41.1 MB/s eta 0:00:01
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp38-cp38-manylinux2014_x86_64.whl (35 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp38-cp38-manylinux2014_x86_64.whl (20 kB)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.5-cp38-cp38-manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 63.5 MB/s eta 0:00:01
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp38-cp38-manylinux2014_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 135.6 MB/s eta 0:00:01
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (8.1.2)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (2.4.7)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp38-cp38-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 86.5 MB/s eta 0:00:01
# Collecting joblib>=0.11
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 66.7 MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 20)) (2021.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from Jinja2>=2.10.1->flask==1.1.2->-r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (2020.12.5)
# Collecting ply>=3.4
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 7.9 MB/s  eta 0:00:01
# Building wheels for collected packages: wikiextractor, sklearn
#   Building wheel for wikiextractor (setup.py) ... done
#   Created wheel for wikiextractor: filename=wikiextractor-0.1-py3-none-any.whl size=38819 sha256=538678d615f9fb49eb69c14979e0b9c6ba70784cb55bd58fd7516d1fad964549
#   Stored in directory: /root/.cache/pip/wheels/98/50/4b/5a06f4f998b52f6b828af95aa4e1b3efb784b3210c970bcaf3
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=287f062fd39ebd26935a2412497acbeae974520a17e5ac311c9847aaf58292aa
#   Stored in directory: /root/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built wikiextractor sklearn
# Installing collected packages: wikiextractor, sentencepiece, ninja, emoji, Werkzeug, itsdangerous, click, flask, gunicorn, python-dotenv, ply, stone, dropbox, dataclasses, srsly, wasabi, blis, cymem, murmurhash, preshed, catalogue, plac, thinc, spacy, cycler, kiwisolver, matplotlib, scipy, joblib, threadpoolctl, scikit-learn, fastprogress, sklearn, pandas
# Successfully installed Werkzeug-1.0.1 blis-0.7.4 catalogue-1.0.0 click-7.1.2 cycler-0.10.0 cymem-2.0.5 dataclasses-0.6 dropbox-11.2.0 emoji-1.2.0 fastprogress-1.0.0 flask-1.1.2 gunicorn-20.0.4 itsdangerous-1.1.0 joblib-1.0.1 kiwisolver-1.3.1 matplotlib-3.4.1 murmurhash-1.0.5 ninja-1.10.0 pandas-1.2.4 plac-1.1.3 ply-3.11 preshed-3.0.5 python-dotenv-0.15.0 scikit-learn-0.24.1 scipy-1.6.1 sentencepiece-0.1.95 sklearn-0.0 spacy-2.3.5 srsly-1.0.5 stone-3.2.1 thinc-7.4.5 threadpoolctl-2.1.0 wasabi-0.8.2 wikiextractor-0.1
# Cloning into 'fastai1'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 155 (delta 29), reused 131 (delta 18), pack-reused 0
# Receiving objects: 100% (155/155), 207.89 KiB | 675.00 KiB/s, done.
# Resolving deltas: 100% (29/29), done.
# Cloning into 'Best-Deep-Learning-Optimizers'...
# remote: Enumerating objects: 211, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 211 (delta 14), reused 3 (delta 1), pack-reused 178
# Receiving objects: 100% (211/211), 858.72 KiB | 7.67 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
from AdaptTextLib.adapttext.adapt_text import AdaptText

lang = 'si'
app_root = "/storage"
bs = 128
splitting_ratio = 0.1
adapttext = AdaptText(lang, app_root, bs, splitting_ratio)

# %%
adapttext.prepare_pretrained_lm("full_si_dedup.zip")

# %%
import pandas as pd

pd.set_option('display.max_colwidth', -1)
# path_to_csv="sinhala-hate-speech-dataset.csv"
path_to_csv="Sinhala_news_articles.csv"
# path_to_csv="small_sin.csv"
df = pd.read_csv(path_to_csv)

text_name = "Title"
label_name = "Label"

# print(df.head())

classifierModelFWD, classifierModelBWD, ensembleModel, classes = adapttext.build_classifier(df, text_name, label_name, grad_unfreeze=True)
# Out:
# International    12009
# Sport            9088
# Business         5323
# Name: Label, dtype: int64
# International    10808
# Sport            8179
# Business         4791
# Name: Label, dtype: int64
# International    10808
# Sport            8179
# Business         4791
# Name: Label, dtype: int64
# Training Forward model...
# [PosixPath('/storage/data/siwiki/models/si_wt'), PosixPath('/storage/data/siwiki/models/si_wt_vocab')]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:05<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>7.097915</td>
#       <td>#na#</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.581296</td>
#       <td>#na#</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='23' class='' max='38' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.53% [23/38 00:01<00:00 13.2997]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 4.79E-02
# Min loss divided by 10: 3.02E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.552254</td>
#       <td>4.445662</td>
#       <td>0.692545</td>
#       <td>0.307455</td>
#       <td>85.256302</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.749359</td>
#       <td>4.230561</td>
#       <td>0.679196</td>
#       <td>0.320804</td>
#       <td>68.755783</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 4.445662021636963.
# Better model found at epoch 1 with valid_loss value: 4.230561256408691.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.079358</td>
#       <td>4.283723</td>
#       <td>0.690759</td>
#       <td>0.309241</td>
#       <td>72.509880</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.191518</td>
#       <td>4.471905</td>
#       <td>0.703170</td>
#       <td>0.296830</td>
#       <td>87.523277</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.394401</td>
#       <td>4.687664</td>
#       <td>0.717723</td>
#       <td>0.282277</td>
#       <td>108.599197</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.895580</td>
#       <td>0.104420</td>
#       <td>nan</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.895580</td>
#       <td>0.104420</td>
#       <td>nan</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.895580</td>
#       <td>0.104420</td>
#       <td>nan</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.895580</td>
#       <td>0.104420</td>
#       <td>nan</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.895580</td>
#       <td>0.104420</td>
#       <td>nan</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 4.2837233543396.
# Epoch 1: reducing lr to 0.0358806475022747
# Epoch 2: reducing lr to 0.0371993298391169
# Epoch 3: reducing lr to 0.031050506620329207
# Epoch 4: reducing lr to 0.0212587873483572
# Epoch 5: reducing lr to 0.010820353233977759
# Epoch 6: reducing lr to 0.002929274623239279
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='96' class='' max='743' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.92% [96/743 00:02<00:16 0.9521]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.20E-03
# Min loss divided by 10: 5.25E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.276213</td>
#       <td>0.201833</td>
#       <td>0.937169</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.199414</td>
#       <td>0.165462</td>
#       <td>0.944360</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.176480</td>
#       <td>0.151785</td>
#       <td>0.947767</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.176518</td>
#       <td>0.145875</td>
#       <td>0.953444</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.178654</td>
#       <td>0.153851</td>
#       <td>0.942846</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.152566</td>
#       <td>0.145811</td>
#       <td>0.950795</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.135411</td>
#       <td>0.147515</td>
#       <td>0.947767</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.131413</td>
#       <td>0.153691</td>
#       <td>0.945874</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.132278</td>
#       <td>0.147801</td>
#       <td>0.946631</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.120792</td>
#       <td>0.144353</td>
#       <td>0.949281</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.111384</td>
#       <td>0.143149</td>
#       <td>0.949659</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.100778</td>
#       <td>0.142937</td>
#       <td>0.951173</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.2018326371908188.
# Better model found at epoch 1 with valid_loss value: 0.16546209156513214.
# Better model found at epoch 2 with valid_loss value: 0.15178488194942474.
# Better model found at epoch 3 with valid_loss value: 0.1458747833967209.
# Epoch 4: reducing lr to 0.0008973019456161324
# Better model found at epoch 5 with valid_loss value: 0.14581146836280823.
# Better model found at epoch 9 with valid_loss value: 0.14435312151908875.
# Better model found at epoch 10 with valid_loss value: 0.14314913749694824.
# Better model found at epoch 11 with valid_loss value: 0.14293676614761353.
# The accuracy is 0.9511733651161194 %.
# Gradual Unfreezing..
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.101350</td>
#       <td>0.148871</td>
#       <td>0.951930</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.136007</td>
#       <td>0.149821</td>
#       <td>0.947767</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.109859</td>
#       <td>0.146804</td>
#       <td>0.951930</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.092987</td>
#       <td>0.143540</td>
#       <td>0.953066</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.071593</td>
#       <td>0.151649</td>
#       <td>0.951173</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.061641</td>
#       <td>0.151713</td>
#       <td>0.948524</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.044187</td>
#       <td>0.152713</td>
#       <td>0.952309</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.040667</td>
#       <td>0.150604</td>
#       <td>0.952687</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.14887145161628723.
# Epoch 1: reducing lr to 0.0009000273271860685
# Better model found at epoch 2 with valid_loss value: 0.14680369198322296.
# Better model found at epoch 3 with valid_loss value: 0.14353978633880615.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.066615</td>
#       <td>0.146000</td>
#       <td>0.954580</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.091645</td>
#       <td>0.157001</td>
#       <td>0.948145</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.071392</td>
#       <td>0.158583</td>
#       <td>0.946631</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.035700</td>
#       <td>0.152619</td>
#       <td>0.958365</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.020585</td>
#       <td>0.166901</td>
#       <td>0.952309</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.018506</td>
#       <td>0.161037</td>
#       <td>0.954580</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.1460002213716507.
# Epoch 1: reducing lr to 0.0009564127291386634
# Completely Unfreezing..
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='70' class='' max='743' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       9.42% [70/743 00:03<00:34 0.0999]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 7.59E-05
# Min loss divided by 10: 9.12E-08
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.056436</td>
#       <td>0.141798</td>
#       <td>0.952309</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.053825</td>
#       <td>0.146580</td>
#       <td>0.951173</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.034317</td>
#       <td>0.143454</td>
#       <td>0.952687</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.033440</td>
#       <td>0.141452</td>
#       <td>0.953444</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.041655</td>
#       <td>0.142145</td>
#       <td>0.955715</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.034570</td>
#       <td>0.140650</td>
#       <td>0.956094</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.14179757237434387.
# Better model found at epoch 3 with valid_loss value: 0.14145216345787048.
# Better model found at epoch 5 with valid_loss value: 0.14064982533454895.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.028775</td>
#       <td>0.143714</td>
#       <td>0.953066</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.027750</td>
#       <td>0.143960</td>
#       <td>0.953823</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.026271</td>
#       <td>0.145450</td>
#       <td>0.954201</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.022450</td>
#       <td>0.144641</td>
#       <td>0.954580</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.024408</td>
#       <td>0.145048</td>
#       <td>0.953823</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.019946</td>
#       <td>0.144830</td>
#       <td>0.953444</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.14371418952941895.
# The accuracy is 0.9530658721923828 %.
# Training Backward model...
# [PosixPath('/storage/data/siwiki/models/si_wt_bwd'), PosixPath('/storage/data/siwiki/models/si_wt_vocab_bwd')]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:04<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.808933</td>
#       <td>#na#</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.389683</td>
#       <td>#na#</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='23' class='' max='38' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.53% [23/38 00:01<00:00 12.8424]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.20E-01
# Min loss divided by 10: 2.51E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.982126</td>
#       <td>5.138528</td>
#       <td>0.729509</td>
#       <td>0.270491</td>
#       <td>170.464798</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.366774</td>
#       <td>4.716680</td>
#       <td>0.704107</td>
#       <td>0.295893</td>
#       <td>111.796539</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 5.138528347015381.
# Better model found at epoch 1 with valid_loss value: 4.71668004989624.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.517877</td>
#       <td>4.586674</td>
#       <td>0.698170</td>
#       <td>0.301830</td>
#       <td>98.167305</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.634229</td>
#       <td>12.938739</td>
#       <td>0.992545</td>
#       <td>0.007455</td>
#       <td>416124.125000</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.894196</td>
#       <td>0.105804</td>
#       <td>nan</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.894196</td>
#       <td>0.105804</td>
#       <td>nan</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.894196</td>
#       <td>0.105804</td>
#       <td>nan</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.894196</td>
#       <td>0.105804</td>
#       <td>nan</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.894196</td>
#       <td>0.105804</td>
#       <td>nan</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.894196</td>
#       <td>0.105804</td>
#       <td>nan</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 4.586673736572266.
# Epoch 1: reducing lr to 0.09012811161474202
# Epoch 2: reducing lr to 0.09344049188412727
# Epoch 3: reducing lr to 0.07799534627110338
# Epoch 4: reducing lr to 0.053399659490686015
# Epoch 5: reducing lr to 0.027179498472569563
# Epoch 6: reducing lr to 0.007358005180280089
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='96' class='' max='743' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.92% [96/743 00:02<00:16 0.9863]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 3.02E-03
# Min loss divided by 10: 1.10E-01
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.237352</td>
#       <td>0.218650</td>
#       <td>0.917487</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.233690</td>
#       <td>0.197487</td>
#       <td>0.927706</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.240301</td>
#       <td>0.203159</td>
#       <td>0.925435</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.218440</td>
#       <td>0.190767</td>
#       <td>0.925057</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.213005</td>
#       <td>0.193374</td>
#       <td>0.929220</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.200819</td>
#       <td>0.180877</td>
#       <td>0.931491</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.214743</td>
#       <td>0.184882</td>
#       <td>0.931870</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.184042</td>
#       <td>0.185950</td>
#       <td>0.932627</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.173076</td>
#       <td>0.182840</td>
#       <td>0.933762</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.165035</td>
#       <td>0.176256</td>
#       <td>0.934898</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.164192</td>
#       <td>0.173792</td>
#       <td>0.936033</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.169385</td>
#       <td>0.184913</td>
#       <td>0.931113</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.2186504304409027.
# Better model found at epoch 1 with valid_loss value: 0.19748659431934357.
# Epoch 2: reducing lr to 0.0022610500413670627
# Better model found at epoch 3 with valid_loss value: 0.19076672196388245.
# Epoch 4: reducing lr to 0.0022539205821603117
# Better model found at epoch 5 with valid_loss value: 0.1808769702911377.
# Epoch 6: reducing lr to 0.0015637659952123595
# Epoch 7: reducing lr to 0.001117482411783499
# Better model found at epoch 9 with valid_loss value: 0.17625628411769867.
# Better model found at epoch 10 with valid_loss value: 0.17379172146320343.
# The accuracy is 0.936033308506012 %.
# Gradual Unfreezing..
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.165372</td>
#       <td>0.190036</td>
#       <td>0.933005</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.188628</td>
#       <td>0.175533</td>
#       <td>0.934898</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.149068</td>
#       <td>0.175656</td>
#       <td>0.931491</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.140038</td>
#       <td>0.171297</td>
#       <td>0.936033</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.113355</td>
#       <td>0.165724</td>
#       <td>0.933762</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.103953</td>
#       <td>0.165617</td>
#       <td>0.937169</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.071099</td>
#       <td>0.170436</td>
#       <td>0.941332</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.079917</td>
#       <td>0.169179</td>
#       <td>0.942089</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.19003643095493317.
# Better model found at epoch 1 with valid_loss value: 0.17553281784057617.
# Epoch 2: reducing lr to 0.00234811999360593
# Better model found at epoch 3 with valid_loss value: 0.17129665613174438.
# Better model found at epoch 4 with valid_loss value: 0.16572408378124237.
# Better model found at epoch 5 with valid_loss value: 0.16561727225780487.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.124310</td>
#       <td>0.179074</td>
#       <td>0.937926</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.141202</td>
#       <td>0.165425</td>
#       <td>0.936790</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.108731</td>
#       <td>0.161364</td>
#       <td>0.940575</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.047529</td>
#       <td>0.186293</td>
#       <td>0.943982</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.030492</td>
#       <td>0.182747</td>
#       <td>0.945117</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.023990</td>
#       <td>0.195867</td>
#       <td>0.945496</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.1790742725133896.
# Better model found at epoch 1 with valid_loss value: 0.16542451083660126.
# Better model found at epoch 2 with valid_loss value: 0.16136404871940613.
# Epoch 3: reducing lr to 0.001117482411783499
# Completely Unfreezing..
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='74' class='' max='743' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       9.96% [74/743 00:04<00:36 0.1116]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 7.59E-05
# Min loss divided by 10: 1.10E-07
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.053414</td>
#       <td>0.158232</td>
#       <td>0.942468</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.042765</td>
#       <td>0.158439</td>
#       <td>0.946631</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.033468</td>
#       <td>0.159496</td>
#       <td>0.947388</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.031133</td>
#       <td>0.154589</td>
#       <td>0.948145</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.026655</td>
#       <td>0.160149</td>
#       <td>0.947767</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.033605</td>
#       <td>0.160797</td>
#       <td>0.947010</td>
#       <td>00:26</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.15823233127593994.
# Better model found at epoch 3 with valid_loss value: 0.154588520526886.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.035080</td>
#       <td>0.160130</td>
#       <td>0.949281</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.022385</td>
#       <td>0.160203</td>
#       <td>0.948524</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.021697</td>
#       <td>0.161005</td>
#       <td>0.948902</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.024225</td>
#       <td>0.164093</td>
#       <td>0.948524</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.028735</td>
#       <td>0.162557</td>
#       <td>0.949281</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.018753</td>
#       <td>0.165801</td>
#       <td>0.950038</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.1601298749446869.
# The accuracy is 0.949280858039856 %.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:03<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.751712</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.373051</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='19' class='' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       51.35% [19/37 00:01<00:01 0.5017]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 9.12E-05
# Min loss divided by 10: 6.31E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.552259</td>
#       <td>0.249896</td>
#       <td>0.034091</td>
#       <td>0.965909</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.279146</td>
#       <td>0.105426</td>
#       <td>0.034091</td>
#       <td>0.965909</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.198681</td>
#       <td>0.099555</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.165312</td>
#       <td>0.097158</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.148076</td>
#       <td>0.093659</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.139095</td>
#       <td>0.094338</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.132457</td>
#       <td>0.094231</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.128280</td>
#       <td>0.094401</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.24989601969718933.
# Better model found at epoch 1 with valid_loss value: 0.10542592406272888.
# Better model found at epoch 2 with valid_loss value: 0.09955500811338425.
# Better model found at epoch 3 with valid_loss value: 0.09715786576271057.
# Better model found at epoch 4 with valid_loss value: 0.0936594158411026.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.128925</td>
#       <td>0.093039</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.132180</td>
#       <td>0.095753</td>
#       <td>0.034091</td>
#       <td>0.965909</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.135305</td>
#       <td>0.095914</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.131223</td>
#       <td>0.094814</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.129456</td>
#       <td>0.094498</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.126398</td>
#       <td>0.095145</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.123180</td>
#       <td>0.093895</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.120597</td>
#       <td>0.094017</td>
#       <td>0.034091</td>
#       <td>0.965909</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.09303887188434601.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.130882</td>
#       <td>0.093867</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.129917</td>
#       <td>0.093896</td>
#       <td>0.030303</td>
#       <td>0.969697</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.126584</td>
#       <td>0.099469</td>
#       <td>0.034091</td>
#       <td>0.965909</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.128622</td>
#       <td>0.095002</td>
#       <td>0.034091</td>
#       <td>0.965909</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.126996</td>
#       <td>0.096100</td>
#       <td>0.034091</td>
#       <td>0.965909</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.126341</td>
#       <td>0.097403</td>
#       <td>0.034091</td>
#       <td>0.965909</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.125015</td>
#       <td>0.093598</td>
#       <td>0.034091</td>
#       <td>0.965909</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.125543</td>
#       <td>0.096514</td>
#       <td>0.034091</td>
#       <td>0.965909</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9696969985961914.

# %%
from AdaptTextLib.adapttext.evaluator.evaluator import Evaluator

evaluator = Evaluator()
evaluator.evaluate(ensembleModel, classifierModelFWD)
# Out:
# The accuracy is 0.9696969985961914 %.
# The error rate is 0.030303001403808594 %.
# ROC area is 0.9972672829815687
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        64
#            1       0.97      0.97      0.97       117
#            2       0.99      1.00      0.99        83
#
#     accuracy                           0.97       264
#    macro avg       0.97      0.97      0.97       264
# weighted avg       0.97      0.97      0.97       264
#
# --Mathews Correlation Coefficient--
# 0.9531464103649838
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Text</th>
#       <th>Prediction</th>
#       <th>Actual</th>
#       <th>Loss</th>
#       <th>Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxunk ගැබිණි මවක් xxunk වටා xxunk</td>
#       <td>International</td>
#       <td>Sport</td>
#       <td>14.29</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos කෘෂිකර්ම xxunk නීති</td>
#       <td>Business</td>
#       <td>International</td>
#       <td>10.67</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos " xxunk බුල් xxunk " ශරීරය xxunk xxunk xxunk</td>
#       <td>International</td>
#       <td>Business</td>
#       <td>8.62</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos xxunk දින xxunk තට්ටු xxunk ගොඩනැගිල්ලක් xxunk</td>
#       <td>International</td>
#       <td>Business</td>
#       <td>8.31</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup imf ආර්ථික සමුළුව අත්හිටුවයි</td>
#       <td>Business</td>
#       <td>International</td>
#       <td>8.12</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos xxunk සටන් රොබෝ යානය</td>
#       <td>International</td>
#       <td>Business</td>
#       <td>8.11</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos xxunk xxunk සේවා කාලය දීර්ඝ</td>
#       <td>Business</td>
#       <td>Sport</td>
#       <td>8.10</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos xxunk xxunk xxunk xxunk xxunk කොවිඩ් - 19 xxunk සටනට දැවැන්ත xxunk ( ඡායාරූප )</td>
#       <td>International</td>
#       <td>Business</td>
#       <td>7.56</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos අයි සී සී විධායක කමිටු xxunk වැදගත් තීරණ රැසක්</td>
#       <td>International</td>
#       <td>Sport</td>
#       <td>7.20</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos xxunk සිදුවූ මෙන්න</td>
#       <td>International</td>
#       <td>Business</td>
#       <td>7.13</td>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>
