# %%
# !apt-get update
# !apt install -y git
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [31.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2181 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [425 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2546 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2116 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [395 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [24.5 kB]
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1410 kB]
# Fetched 9381 kB in 2s (5734 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   git-man libasn1-8-heimdal libcurl3-gnutls liberror-perl libexpat1
#   libgdbm-compat4 libgdbm5 libgssapi3-heimdal libhcrypto4-heimdal
#   libheimbase1-heimdal libheimntlm0-heimdal libhx509-5-heimdal
#   libkrb5-26-heimdal libldap-2.4-2 libldap-common libnghttp2-14 libperl5.26
#   libpsl5 libroken18-heimdal librtmp1 libsasl2-2 libsasl2-modules
#   libsasl2-modules-db libsqlite3-0 libwind0-heimdal netbase patch perl
#   perl-modules-5.26 publicsuffix
# Suggested packages:
#   gettext-base git-daemon-run | git-daemon-sysvinit git-doc git-el git-email
#   git-gui gitk gitweb git-cvs git-mediawiki git-svn gdbm-l10n
#   libsasl2-modules-gssapi-mit | libsasl2-modules-gssapi-heimdal
#   libsasl2-modules-ldap libsasl2-modules-otp libsasl2-modules-sql ed
#   diffutils-doc perl-doc libterm-readline-gnu-perl
#   | libterm-readline-perl-perl make
# The following NEW packages will be installed:
#   git git-man libasn1-8-heimdal libcurl3-gnutls liberror-perl libexpat1
#   libgdbm-compat4 libgdbm5 libgssapi3-heimdal libhcrypto4-heimdal
#   libheimbase1-heimdal libheimntlm0-heimdal libhx509-5-heimdal
#   libkrb5-26-heimdal libldap-2.4-2 libldap-common libnghttp2-14 libperl5.26
#   libpsl5 libroken18-heimdal librtmp1 libsasl2-2 libsasl2-modules
#   libsasl2-modules-db libsqlite3-0 libwind0-heimdal netbase patch perl
#   perl-modules-5.26 publicsuffix
# 0 upgraded, 31 newly installed, 0 to remove and 10 not upgraded.
# Need to get 13.5 MB of archives.
# After this operation, 82.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 perl-modules-5.26 all 5.26.1-6ubuntu0.5 [2762 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdbm5 amd64 1.14.1-6 [26.0 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdbm-compat4 amd64 1.14.1-6 [6084 B]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libperl5.26 amd64 5.26.1-6ubuntu0.5 [3534 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 perl amd64 5.26.1-6ubuntu0.5 [201 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libexpat1 amd64 2.2.5-3ubuntu0.2 [80.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsqlite3-0 amd64 3.22.0-1ubuntu0.4 [499 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 netbase all 5.4 [12.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpsl5 amd64 0.19.1-5build1 [41.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 publicsuffix all 20180223.1310-1 [97.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libroken18-heimdal amd64 7.5.0+dfsg-1 [41.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libasn1-8-heimdal amd64 7.5.0+dfsg-1 [175 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libheimbase1-heimdal amd64 7.5.0+dfsg-1 [29.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhcrypto4-heimdal amd64 7.5.0+dfsg-1 [85.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwind0-heimdal amd64 7.5.0+dfsg-1 [47.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhx509-5-heimdal amd64 7.5.0+dfsg-1 [107 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libkrb5-26-heimdal amd64 7.5.0+dfsg-1 [206 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libheimntlm0-heimdal amd64 7.5.0+dfsg-1 [14.8 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgssapi3-heimdal amd64 7.5.0+dfsg-1 [96.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules-db amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [15.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-2 amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [49.2 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-common all 2.4.45+dfsg-1ubuntu1.10 [15.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-2.4-2 amd64 2.4.45+dfsg-1ubuntu1.10 [154 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnghttp2-14 amd64 1.30.0-1ubuntu1 [77.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 librtmp1 amd64 2.4+20151223.gitfa8646d.1-1 [54.2 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcurl3-gnutls amd64 7.58.0-2ubuntu3.13 [218 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 liberror-perl all 0.17025-1 [22.8 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 git-man all 1:2.17.1-1ubuntu0.8 [804 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 git amd64 1:2.17.1-1ubuntu0.8 [3916 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [48.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 patch amd64 2.7.6-2ubuntu1.1 [102 kB]
# Fetched 13.5 MB in 1s (22.5 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package perl-modules-5.26.
# (Reading database ... 6773 files and directories currently installed.)
# Preparing to unpack .../00-perl-modules-5.26_5.26.1-6ubuntu0.5_all.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking perl-modules-5.26 (5.26.1-6ubuntu0.5) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libgdbm5:amd64.
# Preparing to unpack .../01-libgdbm5_1.14.1-6_amd64.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking libgdbm5:amd64 (1.14.1-6) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libgdbm-compat4:amd64.
# Preparing to unpack .../02-libgdbm-compat4_1.14.1-6_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libgdbm-compat4:amd64 (1.14.1-6) ...
# 7Progress: [  5%] [##........................................................] 8Selecting previously unselected package libperl5.26:amd64.
# Preparing to unpack .../03-libperl5.26_5.26.1-6ubuntu0.5_amd64.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking libperl5.26:amd64 (5.26.1-6ubuntu0.5) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package perl.
# Preparing to unpack .../04-perl_5.26.1-6ubuntu0.5_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking perl (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package libexpat1:amd64.
# Preparing to unpack .../05-libexpat1_2.2.5-3ubuntu0.2_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libexpat1:amd64 (2.2.5-3ubuntu0.2) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libsqlite3-0:amd64.
# Preparing to unpack .../06-libsqlite3-0_3.22.0-1ubuntu0.4_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libsqlite3-0:amd64 (3.22.0-1ubuntu0.4) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package netbase.
# Preparing to unpack .../07-netbase_5.4_all.deb ...
# 7Progress: [ 14%] [########..................................................] 8Unpacking netbase (5.4) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libpsl5:amd64.
# Preparing to unpack .../08-libpsl5_0.19.1-5build1_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking libpsl5:amd64 (0.19.1-5build1) ...
# 7Progress: [ 17%] [##########................................................] 8Selecting previously unselected package publicsuffix.
# Preparing to unpack .../09-publicsuffix_20180223.1310-1_all.deb ...
# Unpacking publicsuffix (20180223.1310-1) ...
# 7Progress: [ 19%] [##########................................................] 87Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libroken18-heimdal:amd64.
# Preparing to unpack .../10-libroken18-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libroken18-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 21%] [###########...............................................] 87Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libasn1-8-heimdal:amd64.
# Preparing to unpack .../11-libasn1-8-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libasn1-8-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 22%] [#############.............................................] 87Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libheimbase1-heimdal:amd64.
# Preparing to unpack .../12-libheimbase1-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libheimbase1-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 24%] [##############............................................] 87Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libhcrypto4-heimdal:amd64.
# Preparing to unpack .../13-libhcrypto4-heimdal_7.5.0+dfsg-1_amd64.deb ...
# Unpacking libhcrypto4-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libwind0-heimdal:amd64.
# Preparing to unpack .../14-libwind0-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 28%] [###############...........................................] 8Unpacking libwind0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libhx509-5-heimdal:amd64.
# Preparing to unpack .../15-libhx509-5-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libhx509-5-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libkrb5-26-heimdal:amd64.
# Preparing to unpack .../16-libkrb5-26-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 31%] [##################........................................] 8Unpacking libkrb5-26-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libheimntlm0-heimdal:amd64.
# Preparing to unpack .../17-libheimntlm0-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking libheimntlm0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libgssapi3-heimdal:amd64.
# Preparing to unpack .../18-libgssapi3-heimdal_7.5.0+dfsg-1_amd64.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libgssapi3-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libsasl2-modules-db:amd64.
# Preparing to unpack .../19-libsasl2-modules-db_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package libsasl2-2:amd64.
# Preparing to unpack .../20-libsasl2-2_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package libldap-common.
# Preparing to unpack .../21-libldap-common_2.4.45+dfsg-1ubuntu1.10_all.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package libldap-2.4-2:amd64.
# Preparing to unpack .../22-libldap-2.4-2_2.4.45+dfsg-1ubuntu1.10_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 44%] [#########################.................................] 87Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libnghttp2-14:amd64.
# Preparing to unpack .../23-libnghttp2-14_1.30.0-1ubuntu1_amd64.deb ...
# Unpacking libnghttp2-14:amd64 (1.30.0-1ubuntu1) ...
# 7Progress: [ 46%] [##########################................................] 87Progress: [ 46%] [##########################................................] 8Selecting previously unselected package librtmp1:amd64.
# Preparing to unpack .../24-librtmp1_2.4+20151223.gitfa8646d.1-1_amd64.deb ...
# Unpacking librtmp1:amd64 (2.4+20151223.gitfa8646d.1-1) ...
# 7Progress: [ 47%] [###########################...............................] 87Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package libcurl3-gnutls:amd64.
# Preparing to unpack .../25-libcurl3-gnutls_7.58.0-2ubuntu3.13_amd64.deb ...
# Unpacking libcurl3-gnutls:amd64 (7.58.0-2ubuntu3.13) ...
# 7Progress: [ 49%] [############################..............................] 87Progress: [ 50%] [#############################.............................] 8Selecting previously unselected package liberror-perl.
# Preparing to unpack .../26-liberror-perl_0.17025-1_all.deb ...
# Unpacking liberror-perl (0.17025-1) ...
# 7Progress: [ 51%] [#############################.............................] 8Selecting previously unselected package git-man.
# Preparing to unpack .../27-git-man_1%3a2.17.1-1ubuntu0.8_all.deb ...
# 7Progress: [ 53%] [##############################............................] 8Unpacking git-man (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 53%] [##############################............................] 8Selecting previously unselected package git.
# Preparing to unpack .../28-git_1%3a2.17.1-1ubuntu0.8_amd64.deb ...
# 7Progress: [ 54%] [###############################...........................] 8Unpacking git (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 55%] [###############################...........................] 8Selecting previously unselected package libsasl2-modules:amd64.
# Preparing to unpack .../29-libsasl2-modules_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# 7Progress: [ 56%] [################################..........................] 8Unpacking libsasl2-modules:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 57%] [#################################.........................] 8Selecting previously unselected package patch.
# Preparing to unpack .../30-patch_2.7.6-2ubuntu1.1_amd64.deb ...
# 7Progress: [ 58%] [#################################.........................] 8Unpacking patch (2.7.6-2ubuntu1.1) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up git-man (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libexpat1:amd64 (2.2.5-3ubuntu0.2) ...
# 7Progress: [ 62%] [###################################.......................] 87Progress: [ 62%] [####################################......................] 8Setting up libnghttp2-14:amd64 (1.30.0-1ubuntu1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libpsl5:amd64 (0.19.1-5build1) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 66%] [######################################....................] 8Setting up libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 67%] [#######################################...................] 8Setting up libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 69%] [#######################################...................] 8Setting up libroken18-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up librtmp1:amd64 (2.4+20151223.gitfa8646d.1-1) ...
# 7Progress: [ 71%] [########################################..................] 87Progress: [ 71%] [#########################################.................] 8Setting up perl-modules-5.26 (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 72%] [##########################################................] 8Setting up libgdbm5:amd64 (1.14.1-6) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up patch (2.7.6-2ubuntu1.1) ...
# 7Progress: [ 74%] [###########################################...............] 87Progress: [ 75%] [###########################################...............] 8Setting up publicsuffix (20180223.1310-1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libheimbase1-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 78%] [############################################..............] 8Setting up libsqlite3-0:amd64 (3.22.0-1ubuntu0.4) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libgdbm-compat4:amd64 (1.14.1-6) ...
# 7Progress: [ 79%] [##############################################............] 87Progress: [ 80%] [##############################################............] 8Setting up libsasl2-modules:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up netbase (5.4) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libwind0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libasn1-8-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 85%] [#################################################.........] 87Progress: [ 85%] [#################################################.........] 8Setting up libhcrypto4-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libhx509-5-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libperl5.26:amd64 (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 89%] [###################################################.......] 8Setting up libkrb5-26-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libheimntlm0-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up perl (5.26.1-6ubuntu0.5) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libgssapi3-heimdal:amd64 (7.5.0+dfsg-1) ...
# 7Progress: [ 94%] [######################################################....] 87Progress: [ 94%] [######################################################....] 8Setting up liberror-perl (0.17025-1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libcurl3-gnutls:amd64 (7.58.0-2ubuntu3.13) ...
# 7Progress: [ 97%] [########################################################..] 87Progress: [ 98%] [########################################################..] 8Setting up git (1:2.17.1-1ubuntu0.8) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for libc-bin (2.27-3ubuntu1.4) ...
#
# 78

# %%
# !git clone https://gitlab.com/AdaptText/AdaptTextLib.git
# Out:
# Cloning into 'AdaptTextLib'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 780 (delta 85), reused 140 (delta 77), pack-reused 632
# Receiving objects: 100% (780/780), 1.43 MiB | 6.70 MiB/s, done.
# Resolving deltas: 100% (519/519), done.

# %%
# !cd AdaptTextLib && bash setup.sh
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 10 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Collecting wikiextractor==0.01
#   Downloading wikiextractor-0.1.tar.gz (36 kB)
# Collecting sentencepiece==0.1.95
#   Downloading sentencepiece-0.1.95-cp38-cp38-manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 15.8 MB/s eta 0:00:01
# Collecting ninja==1.10.0
#   Downloading ninja-1.10.0-py3-none-manylinux1_x86_64.whl (102 kB)
#      |████████████████████████████████| 102 kB 44.1 MB/s eta 0:00:01
# Collecting emoji==1.2.0
#   Downloading emoji-1.2.0-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 41.7 MB/s eta 0:00:01
# Collecting flask==1.1.2
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 7.3 MB/s  eta 0:00:01
# Collecting gunicorn==20.0.4
#   Downloading gunicorn-20.0.4-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 17.0 MB/s  eta 0:00:01
# Requirement already satisfied: torch in /opt/conda/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (1.8.1)
# Collecting python-dotenv==0.15.0
#   Downloading python_dotenv-0.15.0-py2.py3-none-any.whl (18 kB)
# Collecting dropbox==11.2.0
#   Downloading dropbox-11.2.0-py3-none-any.whl (555 kB)
#      |████████████████████████████████| 555 kB 42.6 MB/s eta 0:00:01
# Collecting dataclasses==0.6
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting spacy==2.3.5
#   Downloading spacy-2.3.5-cp38-cp38-manylinux2014_x86_64.whl (10.5 MB)
#      |████████████████████████████████| 10.5 MB 30.1 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (1.19.2)
# Collecting matplotlib
#   Downloading matplotlib-3.4.1-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 97.9 MB/s eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.1-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      |████████████████████████████████| 24.9 MB 29.1 MB/s eta 0:00:01
# Collecting fastprogress
#   Downloading fastprogress-1.0.0-py3-none-any.whl (12 kB)
# Collecting scipy==1.6.1
#   Downloading scipy-1.6.1-cp38-cp38-manylinux1_x86_64.whl (27.3 MB)
#      |████████████████████████████████| 27.3 MB 33.2 MB/s eta 0:00:01
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting pandas
#   Downloading pandas-1.2.4-cp38-cp38-manylinux1_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 27.6 MB/s eta 0:00:01
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Werkzeug>=0.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 120.5 MB/s eta 0:00:01
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 2.0 MB/s  eta 0:00:01
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/conda/lib/python3.8/site-packages (from flask==1.1.2->-r requirements.txt (line 5)) (2.11.3)
# Requirement already satisfied: setuptools>=3.0 in /opt/conda/lib/python3.8/site-packages (from gunicorn==20.0.4->-r requirements.txt (line 6)) (50.3.1.post20201107)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.8/site-packages (from torch->-r requirements.txt (line 8)) (3.7.4.3)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.8/site-packages (from dropbox==11.2.0->-r requirements.txt (line 10)) (1.15.0)
# Requirement already satisfied: requests>=2.16.2 in /opt/conda/lib/python3.8/site-packages (from dropbox==11.2.0->-r requirements.txt (line 10)) (2.24.0)
# Collecting stone>=2.*
#   Downloading stone-3.2.1-py3-none-any.whl (160 kB)
#      |████████████████████████████████| 160 kB 45.0 MB/s eta 0:00:01
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp38-cp38-manylinux2014_x86_64.whl (20 kB)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.5-cp38-cp38-manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 88.9 MB/s eta 0:00:01
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp38-cp38-manylinux2014_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 119.4 MB/s eta 0:00:01
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp38-cp38-manylinux2014_x86_64.whl (35 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.8/site-packages (from spacy==2.3.5->-r requirements.txt (line 12)) (4.51.0)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.5-cp38-cp38-manylinux2014_x86_64.whl (186 kB)
#      |████████████████████████████████| 186 kB 116.3 MB/s eta 0:00:01
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp38-cp38-manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 67.4 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (8.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 14)) (2.8.1)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp38-cp38-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 62.1 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 43.4 MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 20)) (2021.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from Jinja2>=2.10.1->flask==1.1.2->-r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.16.2->dropbox==11.2.0->-r requirements.txt (line 10)) (2.10)
# Collecting ply>=3.4
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 13.4 MB/s eta 0:00:01
# Building wheels for collected packages: wikiextractor, sklearn
#   Building wheel for wikiextractor (setup.py) ... done
#   Created wheel for wikiextractor: filename=wikiextractor-0.1-py3-none-any.whl size=38819 sha256=52c3fb6b10e93f387d1f2f574719ee8f8e3a1fde57d22498693a112ccbb62342
#   Stored in directory: /root/.cache/pip/wheels/98/50/4b/5a06f4f998b52f6b828af95aa4e1b3efb784b3210c970bcaf3
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=0aa4f9ae9058be6d53598857bcea4ec1ff9a52ee016cded44bccaaa55d401412
#   Stored in directory: /root/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built wikiextractor sklearn
# Installing collected packages: wikiextractor, sentencepiece, ninja, emoji, itsdangerous, Werkzeug, click, flask, gunicorn, python-dotenv, ply, stone, dropbox, dataclasses, wasabi, catalogue, murmurhash, srsly, cymem, plac, preshed, blis, thinc, spacy, kiwisolver, cycler, matplotlib, joblib, scipy, threadpoolctl, scikit-learn, fastprogress, sklearn, pandas
# Successfully installed Werkzeug-1.0.1 blis-0.7.4 catalogue-1.0.0 click-7.1.2 cycler-0.10.0 cymem-2.0.5 dataclasses-0.6 dropbox-11.2.0 emoji-1.2.0 fastprogress-1.0.0 flask-1.1.2 gunicorn-20.0.4 itsdangerous-1.1.0 joblib-1.0.1 kiwisolver-1.3.1 matplotlib-3.4.1 murmurhash-1.0.5 ninja-1.10.0 pandas-1.2.4 plac-1.1.3 ply-3.11 preshed-3.0.5 python-dotenv-0.15.0 scikit-learn-0.24.1 scipy-1.6.1 sentencepiece-0.1.95 sklearn-0.0 spacy-2.3.5 srsly-1.0.5 stone-3.2.1 thinc-7.4.5 threadpoolctl-2.1.0 wasabi-0.8.2 wikiextractor-0.1
# Cloning into 'fastai1'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 155 (delta 29), reused 131 (delta 18), pack-reused 0
# Receiving objects: 100% (155/155), 207.89 KiB | 6.30 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# Cloning into 'Best-Deep-Learning-Optimizers'...
# remote: Enumerating objects: 211, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 211 (delta 14), reused 3 (delta 1), pack-reused 178
# Receiving objects: 100% (211/211), 858.72 KiB | 3.50 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
from AdaptTextLib.adapttext.adapt_text import AdaptText

lang = 'si'
app_root = "/storage"
bs = 128
splitting_ratio = 0.1
adapttext = AdaptText(lang, app_root, bs, splitting_ratio)

# %%
adapttext.prepare_pretrained_lm("full_si_dedup.zip")

# %%
import pandas as pd

pd.set_option('display.max_colwidth', -1)
# path_to_csv="sinhala-hate-speech-dataset.csv"
path_to_csv="Sinhala_news_articles.csv"
# path_to_csv="small_sin.csv"
df = pd.read_csv(path_to_csv)

text_name = "Title"
label_name = "Label"

# print(df.head())

classifierModelFWD, classifierModelBWD, ensembleModel, classes = adapttext.build_classifier(df, text_name, label_name, grad_unfreeze=True)
# Out:
# International    12009
# Sport            9088
# Business         5323
# Name: Label, dtype: int64
# International    10808
# Sport            8179
# Business         4791
# Name: Label, dtype: int64
# International    10808
# Sport            8179
# Business         4791
# Name: Label, dtype: int64
# Training Forward model...
# [PosixPath('/storage/data/siwiki/models/si_wt'), PosixPath('/storage/data/siwiki/models/si_wt_vocab')]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:05<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>7.091925</td>
#       <td>#na#</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.570207</td>
#       <td>#na#</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='23' class='' max='38' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.53% [23/38 00:01<00:00 13.3851]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 4.79E-02
# Min loss divided by 10: 3.02E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.558103</td>
#       <td>4.455308</td>
#       <td>0.696161</td>
#       <td>0.303839</td>
#       <td>86.082664</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.757885</td>
#       <td>4.222740</td>
#       <td>0.679330</td>
#       <td>0.320670</td>
#       <td>68.220131</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 4.455307960510254.
# Better model found at epoch 1 with valid_loss value: 4.222740173339844.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.046237</td>
#       <td>4.315720</td>
#       <td>0.690446</td>
#       <td>0.309554</td>
#       <td>74.867516</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.171369</td>
#       <td>4.461829</td>
#       <td>0.703259</td>
#       <td>0.296741</td>
#       <td>86.645897</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.441864</td>
#       <td>4.916503</td>
#       <td>0.742098</td>
#       <td>0.257902</td>
#       <td>136.524475</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.895580</td>
#       <td>0.104420</td>
#       <td>nan</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.895580</td>
#       <td>0.104420</td>
#       <td>nan</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.895580</td>
#       <td>0.104420</td>
#       <td>nan</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.895580</td>
#       <td>0.104420</td>
#       <td>nan</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.895580</td>
#       <td>0.104420</td>
#       <td>nan</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 4.315720081329346.
# Epoch 1: reducing lr to 0.0358806475022747
# Epoch 2: reducing lr to 0.0371993298391169
# Epoch 3: reducing lr to 0.031050506620329207
# Epoch 4: reducing lr to 0.0212587873483572
# Epoch 5: reducing lr to 0.010820353233977759
# Epoch 6: reducing lr to 0.002929274623239279
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='95' class='' max='743' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.79% [95/743 00:02<00:15 0.6716]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 2.51E-03
# Min loss divided by 10: 1.32E-01
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.237463</td>
#       <td>0.175184</td>
#       <td>0.941711</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.231410</td>
#       <td>0.168754</td>
#       <td>0.941711</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.205957</td>
#       <td>0.164462</td>
#       <td>0.939061</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.185347</td>
#       <td>0.154885</td>
#       <td>0.941332</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.163133</td>
#       <td>0.151115</td>
#       <td>0.942468</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.125563</td>
#       <td>0.147449</td>
#       <td>0.944739</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.175510</td>
#       <td>0.149528</td>
#       <td>0.945496</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.132083</td>
#       <td>0.147777</td>
#       <td>0.948145</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.117486</td>
#       <td>0.150508</td>
#       <td>0.943982</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.119998</td>
#       <td>0.150470</td>
#       <td>0.947767</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.105876</td>
#       <td>0.154597</td>
#       <td>0.947010</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.102914</td>
#       <td>0.149846</td>
#       <td>0.948902</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.1751835197210312.
# Better model found at epoch 1 with valid_loss value: 0.16875408589839935.
# Better model found at epoch 2 with valid_loss value: 0.1644623875617981.
# Better model found at epoch 3 with valid_loss value: 0.15488488972187042.
# Better model found at epoch 4 with valid_loss value: 0.1511148065328598.
# Better model found at epoch 5 with valid_loss value: 0.14744918048381805.
# Epoch 6: reducing lr to 0.0013006839012999533
# Epoch 7: reducing lr to 0.0009294813849659511
# The accuracy is 0.9447388052940369 %.
# Gradual Unfreezing..
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.128328</td>
#       <td>0.144449</td>
#       <td>0.947010</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.153307</td>
#       <td>0.148295</td>
#       <td>0.946631</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.112883</td>
#       <td>0.142450</td>
#       <td>0.954958</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.098337</td>
#       <td>0.152435</td>
#       <td>0.944360</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.071237</td>
#       <td>0.145787</td>
#       <td>0.951173</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.065567</td>
#       <td>0.155222</td>
#       <td>0.949659</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.050204</td>
#       <td>0.159391</td>
#       <td>0.953444</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.036299</td>
#       <td>0.154623</td>
#       <td>0.953823</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.14444918930530548.
# Epoch 1: reducing lr to 0.001880423612352757
# Better model found at epoch 2 with valid_loss value: 0.1424497812986374.
# Epoch 3: reducing lr to 0.0016311255838297918
# Epoch 4: reducing lr to 0.0011171741935434337
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.099333</td>
#       <td>0.156991</td>
#       <td>0.942846</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.118821</td>
#       <td>0.149813</td>
#       <td>0.947010</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.086032</td>
#       <td>0.148946</td>
#       <td>0.946631</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.044534</td>
#       <td>0.159264</td>
#       <td>0.949659</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.020586</td>
#       <td>0.166324</td>
#       <td>0.951552</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.012113</td>
#       <td>0.163786</td>
#       <td>0.955715</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.15699149668216705.
# Better model found at epoch 1 with valid_loss value: 0.14981341361999512.
# Better model found at epoch 2 with valid_loss value: 0.14894568920135498.
# Epoch 3: reducing lr to 0.0009294813849659511
# Completely Unfreezing..
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='72' class='' max='743' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       9.69% [72/743 00:03<00:28 0.0697]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 7.59E-07
# Min loss divided by 10: 1.91E-07
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.041395</td>
#       <td>0.147235</td>
#       <td>0.947010</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.038838</td>
#       <td>0.150543</td>
#       <td>0.945874</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.038218</td>
#       <td>0.149648</td>
#       <td>0.946631</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.038643</td>
#       <td>0.146476</td>
#       <td>0.947767</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.046625</td>
#       <td>0.149323</td>
#       <td>0.946631</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.049854</td>
#       <td>0.145946</td>
#       <td>0.946631</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.14723463356494904.
# Better model found at epoch 3 with valid_loss value: 0.1464758813381195.
# Better model found at epoch 5 with valid_loss value: 0.1459464132785797.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.043669</td>
#       <td>0.146464</td>
#       <td>0.947388</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.040383</td>
#       <td>0.147663</td>
#       <td>0.946631</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.039273</td>
#       <td>0.147964</td>
#       <td>0.948145</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.039975</td>
#       <td>0.146639</td>
#       <td>0.947767</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.046978</td>
#       <td>0.145529</td>
#       <td>0.950038</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.041694</td>
#       <td>0.147617</td>
#       <td>0.946253</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.14646433293819427.
# Better model found at epoch 4 with valid_loss value: 0.14552858471870422.
# The accuracy is 0.9500378370285034 %.
# Training Backward model...
# [PosixPath('/storage/data/siwiki/models/si_wt_bwd'), PosixPath('/storage/data/siwiki/models/si_wt_vocab_bwd')]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:04<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.789849</td>
#       <td>#na#</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.370137</td>
#       <td>#na#</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='23' class='' max='38' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.53% [23/38 00:01<00:00 12.8027]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-07
# Min loss divided by 10: 2.51E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.811104</td>
#       <td>6.112317</td>
#       <td>0.833705</td>
#       <td>0.166295</td>
#       <td>451.383392</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.806924</td>
#       <td>6.111591</td>
#       <td>0.834018</td>
#       <td>0.165982</td>
#       <td>451.055695</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 6.112317085266113.
# Better model found at epoch 1 with valid_loss value: 6.111591339111328.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.798983</td>
#       <td>6.111372</td>
#       <td>0.833750</td>
#       <td>0.166250</td>
#       <td>450.957214</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.801836</td>
#       <td>6.105042</td>
#       <td>0.833348</td>
#       <td>0.166652</td>
#       <td>448.112091</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.794224</td>
#       <td>6.094762</td>
#       <td>0.832679</td>
#       <td>0.167321</td>
#       <td>443.528839</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.796572</td>
#       <td>6.083640</td>
#       <td>0.831563</td>
#       <td>0.168437</td>
#       <td>438.622711</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.764269</td>
#       <td>6.063179</td>
#       <td>0.829598</td>
#       <td>0.170402</td>
#       <td>429.739197</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>6.762521</td>
#       <td>6.055747</td>
#       <td>0.829107</td>
#       <td>0.170893</td>
#       <td>426.557617</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>6.757382</td>
#       <td>6.054529</td>
#       <td>0.829018</td>
#       <td>0.170982</td>
#       <td>426.038269</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>6.749279</td>
#       <td>6.053771</td>
#       <td>0.829107</td>
#       <td>0.170893</td>
#       <td>425.715393</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 6.111372470855713.
# Better model found at epoch 1 with valid_loss value: 6.105042457580566.
# Better model found at epoch 2 with valid_loss value: 6.094762325286865.
# Better model found at epoch 3 with valid_loss value: 6.083640098571777.
# Better model found at epoch 4 with valid_loss value: 6.063178539276123.
# Better model found at epoch 5 with valid_loss value: 6.055747032165527.
# Better model found at epoch 6 with valid_loss value: 6.054528713226318.
# Better model found at epoch 7 with valid_loss value: 6.053770542144775.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='95' class='' max='743' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.79% [95/743 00:02<00:14 1.1925]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-03
# Min loss divided by 10: 9.12E-02
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.319213</td>
#       <td>0.240735</td>
#       <td>0.911431</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.303008</td>
#       <td>0.226373</td>
#       <td>0.911431</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.328299</td>
#       <td>0.205928</td>
#       <td>0.920136</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.275237</td>
#       <td>0.237949</td>
#       <td>0.911809</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.294832</td>
#       <td>0.194537</td>
#       <td>0.926192</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.282540</td>
#       <td>0.201694</td>
#       <td>0.923543</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.264452</td>
#       <td>0.191218</td>
#       <td>0.926949</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.262312</td>
#       <td>0.186637</td>
#       <td>0.931113</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.243780</td>
#       <td>0.185729</td>
#       <td>0.929977</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.221999</td>
#       <td>0.181938</td>
#       <td>0.928463</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.238713</td>
#       <td>0.177430</td>
#       <td>0.926949</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.226665</td>
#       <td>0.186176</td>
#       <td>0.929220</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.2407350391149521.
# Better model found at epoch 1 with valid_loss value: 0.22637340426445007.
# Better model found at epoch 2 with valid_loss value: 0.20592841506004333.
# Epoch 3: reducing lr to 0.005019325353298154
# Better model found at epoch 4 with valid_loss value: 0.194536954164505.
# Epoch 5: reducing lr to 0.004096847500965526
# Better model found at epoch 6 with valid_loss value: 0.19121798872947693.
# Better model found at epoch 7 with valid_loss value: 0.18663688004016876.
# Better model found at epoch 8 with valid_loss value: 0.1857290118932724.
# Better model found at epoch 9 with valid_loss value: 0.18193833529949188.
# Better model found at epoch 10 with valid_loss value: 0.1774298995733261.
# The accuracy is 0.9269492626190186 %.
# Gradual Unfreezing..
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.218767</td>
#       <td>0.179570</td>
#       <td>0.929599</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.209045</td>
#       <td>0.181133</td>
#       <td>0.930734</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.170964</td>
#       <td>0.168305</td>
#       <td>0.933384</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.164825</td>
#       <td>0.163968</td>
#       <td>0.938304</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.140159</td>
#       <td>0.167542</td>
#       <td>0.934141</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.113297</td>
#       <td>0.176124</td>
#       <td>0.934898</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.078903</td>
#       <td>0.174570</td>
#       <td>0.939440</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.086783</td>
#       <td>0.177452</td>
#       <td>0.942089</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.1795700341463089.
# Epoch 1: reducing lr to 0.0047234105573591145
# Better model found at epoch 2 with valid_loss value: 0.16830486059188843.
# Better model found at epoch 3 with valid_loss value: 0.16396750509738922.
# Epoch 4: reducing lr to 0.002806214698394405
# Epoch 5: reducing lr to 0.0014286726989277583
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.167017</td>
#       <td>0.175938</td>
#       <td>0.934898</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.172266</td>
#       <td>0.169826</td>
#       <td>0.934898</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.133830</td>
#       <td>0.168453</td>
#       <td>0.939818</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.079825</td>
#       <td>0.168838</td>
#       <td>0.939818</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.035555</td>
#       <td>0.173468</td>
#       <td>0.946253</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.030888</td>
#       <td>0.180612</td>
#       <td>0.945874</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.17593827843666077.
# Better model found at epoch 1 with valid_loss value: 0.1698264628648758.
# Better model found at epoch 2 with valid_loss value: 0.1684528887271881.
# Epoch 3: reducing lr to 0.002334751679236702
# Completely Unfreezing..
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='74' class='' max='743' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       9.96% [74/743 00:03<00:29 0.1256]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 7.59E-07
# Min loss divided by 10: 5.75E-07
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.068053</td>
#       <td>0.168281</td>
#       <td>0.939440</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.085455</td>
#       <td>0.173950</td>
#       <td>0.938304</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.077576</td>
#       <td>0.174500</td>
#       <td>0.938304</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.068861</td>
#       <td>0.164577</td>
#       <td>0.940575</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.083376</td>
#       <td>0.165510</td>
#       <td>0.939818</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.077882</td>
#       <td>0.166047</td>
#       <td>0.940575</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.16828076541423798.
# Better model found at epoch 3 with valid_loss value: 0.16457650065422058.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.076759</td>
#       <td>0.168757</td>
#       <td>0.938304</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.070840</td>
#       <td>0.164938</td>
#       <td>0.940197</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.065522</td>
#       <td>0.164774</td>
#       <td>0.941332</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.071866</td>
#       <td>0.168130</td>
#       <td>0.940197</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.084274</td>
#       <td>0.164333</td>
#       <td>0.940575</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.066645</td>
#       <td>0.168737</td>
#       <td>0.938683</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.16875694692134857.
# Better model found at epoch 1 with valid_loss value: 0.16493788361549377.
# Better model found at epoch 2 with valid_loss value: 0.16477413475513458.
# Better model found at epoch 4 with valid_loss value: 0.16433264315128326.
# The accuracy is 0.9405753016471863 %.
# ps ifnone
# [0, 0]
# ------------
# ps listify
# [0, 0]
# ------------
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:02<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.880604</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.485022</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='22' class='' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       59.46% [22/37 00:00<00:00 0.9984]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.45E-03
# Min loss divided by 10: 1.58E-01
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.503780</td>
#       <td>0.265592</td>
#       <td>0.041667</td>
#       <td>0.958333</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.273233</td>
#       <td>0.159129</td>
#       <td>0.053030</td>
#       <td>0.946970</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.201463</td>
#       <td>0.153500</td>
#       <td>0.053030</td>
#       <td>0.946970</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.175122</td>
#       <td>0.159089</td>
#       <td>0.045455</td>
#       <td>0.954545</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.155833</td>
#       <td>0.155193</td>
#       <td>0.056818</td>
#       <td>0.943182</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.147390</td>
#       <td>0.158854</td>
#       <td>0.053030</td>
#       <td>0.946970</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.139548</td>
#       <td>0.161129</td>
#       <td>0.056818</td>
#       <td>0.943182</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.137434</td>
#       <td>0.156243</td>
#       <td>0.056818</td>
#       <td>0.943182</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.26559197902679443.
# Better model found at epoch 1 with valid_loss value: 0.15912914276123047.
# Better model found at epoch 2 with valid_loss value: 0.1535002738237381.
# Epoch 3: reducing lr to 0.0009347487890607825
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.146576</td>
#       <td>0.157985</td>
#       <td>0.056818</td>
#       <td>0.943182</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.146220</td>
#       <td>0.152309</td>
#       <td>0.049242</td>
#       <td>0.950758</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.146415</td>
#       <td>0.153611</td>
#       <td>0.053030</td>
#       <td>0.946970</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.148868</td>
#       <td>0.147292</td>
#       <td>0.049242</td>
#       <td>0.950758</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.146100</td>
#       <td>0.150389</td>
#       <td>0.049242</td>
#       <td>0.950758</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.141608</td>
#       <td>0.153725</td>
#       <td>0.053030</td>
#       <td>0.946970</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.137958</td>
#       <td>0.146726</td>
#       <td>0.053030</td>
#       <td>0.946970</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.135261</td>
#       <td>0.148814</td>
#       <td>0.049242</td>
#       <td>0.950758</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.15798522531986237.
# Better model found at epoch 1 with valid_loss value: 0.15230900049209595.
# Better model found at epoch 3 with valid_loss value: 0.14729198813438416.
# Better model found at epoch 6 with valid_loss value: 0.14672572910785675.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.129001</td>
#       <td>0.148779</td>
#       <td>0.049242</td>
#       <td>0.950758</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.132506</td>
#       <td>0.153963</td>
#       <td>0.056818</td>
#       <td>0.943182</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.133509</td>
#       <td>0.154801</td>
#       <td>0.049242</td>
#       <td>0.950758</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.129708</td>
#       <td>0.144899</td>
#       <td>0.053030</td>
#       <td>0.946970</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.125206</td>
#       <td>0.155166</td>
#       <td>0.053030</td>
#       <td>0.946970</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.126413</td>
#       <td>0.146785</td>
#       <td>0.049242</td>
#       <td>0.950758</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.127141</td>
#       <td>0.147677</td>
#       <td>0.053030</td>
#       <td>0.946970</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.123558</td>
#       <td>0.157931</td>
#       <td>0.053030</td>
#       <td>0.946970</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9507575631141663.

# %%
from AdaptTextLib.adapttext.evaluator.evaluator import Evaluator

evaluator = Evaluator()
evaluator.evaluate(ensembleModel, classifierModelFWD)
# Out:
# The accuracy is 0.9507575631141663 %.
# The error rate is 0.04924243688583374 %.
# ROC area is 0.992615849758707
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91        64
#            1       0.95      0.96      0.95       117
#            2       0.99      0.96      0.98        83
#
#     accuracy                           0.95       264
#    macro avg       0.95      0.95      0.95       264
# weighted avg       0.95      0.95      0.95       264
#
# --Mathews Correlation Coefficient--
# 0.9238068466227267
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Text</th>
#       <th>Prediction</th>
#       <th>Actual</th>
#       <th>Loss</th>
#       <th>Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxunk ගැබිණි මවක් xxunk වටා xxunk</td>
#       <td>International</td>
#       <td>Sport</td>
#       <td>14.46</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos කෘෂිකර්ම xxunk නීති</td>
#       <td>Business</td>
#       <td>International</td>
#       <td>6.65</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup adb සභාපති දිවයිනට</td>
#       <td>Sport</td>
#       <td>Business</td>
#       <td>5.94</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos xxunk සටන් රොබෝ යානය</td>
#       <td>International</td>
#       <td>Business</td>
#       <td>5.89</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos xxunk xxunk ශ්‍රී ලංකාව^ ඉන්දියාව පරදයි</td>
#       <td>Sport</td>
#       <td>Business</td>
#       <td>5.81</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos කාර්යාල සේවකයන්ට කෑම පැය xxunk පැයක්</td>
#       <td>Business</td>
#       <td>International</td>
#       <td>5.71</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos කටුනායක ධාවන xxunk වැඩකටයුතු xxunk අවසන්</td>
#       <td>Sport</td>
#       <td>Business</td>
#       <td>5.53</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup imf ආර්ථික සමුළුව අත්හිටුවයි</td>
#       <td>Business</td>
#       <td>International</td>
#       <td>5.48</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos xxunk xxunk සේවා කාලය දීර්ඝ</td>
#       <td>Business</td>
#       <td>Sport</td>
#       <td>5.14</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <td>xxbos xxunk දින xxunk තට්ටු xxunk ගොඩනැගිල්ලක් xxunk</td>
#       <td>International</td>
#       <td>Business</td>
#       <td>5.09</td>
#       <td>0.01</td>
#     </tr>
#   </tbody>
# </table>
